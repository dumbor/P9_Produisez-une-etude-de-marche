# %% [markdown]
# <img src="logo.png" alt="La poule qui chante" style="width: 400px;" align="left"/>

# %% [markdown]
# # Contexte
# Vous travaillez chez La poule qui chante, une entreprise française d’agroalimentaire. Elle souhaite se développer à l'international.<br>
# L'international, oui, mais pour l'instant, le champ des possibles est bien large : aucun pays particulier ni aucun continent n'est pour le moment choisi. Tous les pays sont envisageables !

# %% [markdown]
# # Initialisation du projet

# %% [markdown]
# ## Import des librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

from scipy import stats as st

#Librairies utiliséees pour l'analyse
#Clustering
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering # pour faire du clustering
from sklearn.metrics import silhouette_score # poour calculer le cof de silhouette

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

#Calcul coeff Cophenet
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

# Visualisation coude et silhouette
from yellowbrick.cluster.elbow import kelbow_visualizer
from yellowbrick.cluster import SilhouetteVisualizer

# Calcul distorsion
from scipy.spatial.distance import cdist 

#ACP
#from sklearn import decomposition
from sklearn.decomposition import PCA
from sklearn import preprocessing

# Impute Nan values
from sklearn.impute import KNNImputer 

#from functions import plot_dendrogram


from termcolor import colored # to format text

# %% [markdown]
# ## Paramètres

# %%
# %matplotlib inline 
# On indique que l'on veut voir apparaître les graphiques dans le notebook, sinon on ne verrait rien

pd.set_option('max_colwidth', 100)
pd.set_option('display.max_rows', 45)
pd.set_option('display.max_columns', 20)

# %% [markdown]
# ## Import des fichiers

# %%
path='./Fichiers/'
food_avail=pd.read_csv(path+"DisponibiliteAlimentaire_2017.csv")
population=pd.read_csv(path+"Population_2000_2018.csv")
region=pd.read_excel(path+"List_of_countries.xlsx")

# %% [markdown]
# ## Variables
# Besoin journaliers en protéines
# L’ANR en protéines est de 0,8 g de protéines par kg de poids corporel par jour chez les adultes.
# Cela représente la quantité minimum de protéines qui permet d’éviter la perte de masse corporelle maigre.<br>
# Cette valeur ne concerne que la tranche des adultes qui représente 65,43% ([source](https://donnees.banquemondiale.org/indicator/SP.POP.65UP.TO.ZS?end=2017&start=1960)) de la population, mais est trop basse pour les autres tranches d'âge.<br>
# Nous utiliserons tout de même cette donnée.
#
# D'après le BMC Pubmic Health, le poids moyen est quant à lui de 62kg ([Source](http://webcache.googleusercontent.com/search?q=cache:eOMWwpP7KKEJ:https://politiquedesante.fr/poids-de-lhumanite/&client=firefox-b-d&hl=fr&gl=fr&strip=1&vwsrc=0)).
#
# Ce qui donne un apport recommandé de 62 * 0.8 = 49.6 grammes par jour et par humain.

# %%
prot=49.6

# %% [markdown]
# ## Fonctions

# %%
def mean_and_standard_deviation_info(X) :

    ''' 
    Displays the mean and std of a datadrame
    Parameters : dataframe
    '''

# Observation des moyennes et écart-types du tableau
    return print (
f'''Moyennes:
{X.mean()}

Ecart-type :
{X.std()}
''')

# %%
def plot_dendrogram(data, Z, threshold):
    '''
    Plot dendrogram
    Parameters : 
        - data = data centered and reduced
        - method = the dendrogram method (see linkage doc)
        - metric = the dendrogram metric (see linkage doc)
        - threshold = where I cut my tree to have the number of classification thah I've chosen after 1st observation, the max distance.
    '''
#Z = linkage(data, method=method,metric=metric)

    # Show dendrogram
    fig = plt.figure(figsize=(30, 15))
    c, coph_dists = cophenet(Z, pdist(data))
    plt.title(f'CAH avec matérialisation des classes - cophenet coefficient = {c:.3}', loc='center', fontsize=20, fontweight=0, pad=20)

    dendrogram(Z,labels= names ,orientation='top',color_threshold=threshold,leaf_font_size=12)

    plt.axhline(y=threshold,linestyle = '--') # To materialize the cutting, we use the threshold which cuts the dendogram on the axis of the Ward method.
    plt.show()

# %%
def display_countries_from_clusters(number_of_clusters, groups):
    '''
    Displays the countries of each cluster
    Parameters : 
        - Number of clusters (see colored classes on dendrogram to know the number)
        - Groups of countries
        '''
    print(f"Affichage des {number_of_clusters} clusters")
    print("")
    for i in range(1,len(np.unique(groups))+1):
        print(f"Cluster {i} :")
        print(f", ".join(main_df.index[groups == i].sort_values()))
        print(" ")

# %%
def build_plot(data_frame,var, clustering_method):
    """
    Fonction pour croiser des variables qualitatives 
    et quantitatives en fonction d'une variable qualitative.
    """
    
    #if (np.issubdtype(dfdata[explicative].dtype, np.number)) :
    plt.figure(figsize=(10,5))
    sns.boxplot(data=data_frame,x=var,y=clustering_method,orient="h")

    plt.xlabel(var,fontsize=10)
    plt.ylabel(clustering_method,fontsize=10)
    plt.title(var + " selon " + clustering_method ,fontsize=15, pad=20)

# %%
def display_scree_plot(ratio_var, ratio_var_cumsum):
    '''
    Diagramme décrivant le pourcentage d'intertie totale associé à chaque axe : c'est le diagramme de l'éboulis des valeurs propres.
    On affiche également la somme cumulée des inerties et la visualisation de l'éboulis en ligne pour voir le coude.
    '''
    #ratio_var= pca.explained_variance_ratio_*100 # Pourcentage de variance cumulé expliqué par les n premières composantes.
    plt.bar(np.arange(len(ratio_var)), ratio_var, label="Scree of eigen values")
    plt.plot(np.arange(len(ratio_var)), ratio_var_cumsum,c="red",marker='o', label="Scree of eigen values")
    plt.plot(np.arange(len(ratio_var)), ratio_var,c="purple",marker='_', label="Elbow viz")
    
    plt.xlabel("Number of components")
    plt.ylabel("Percentage of explained variance",)
    plt.title("Scree of eigen values and elbow viz")
    plt.xticks(range(len(ratio_var)))
    plt.legend()
    plt.show()

# %%
def display_factorial_planes(X_projected, n_comp,  axis_ranks, alpha=1, pca=None,illustrative_var=None, labels=None, title_type=None,title_nb_of_indiv=None, method=None):
    '''
    Factorial planes to visualize the distribution of individuals or centroids.
    '''
    for d1,d2 in axis_ranks:
        if d2 < n_comp:

            # initialisation de la figure       
            fig = plt.figure(figsize=(30,30))
            plt.grid(visible=None)
        
            # affichage des points
            if illustrative_var is None:
                plt.scatter(X_projected[:, d1], X_projected[:, d2], alpha=alpha, s=200)
            else:
                illustrative_var = np.array(illustrative_var)
                for value in np.unique(illustrative_var):
                    selected = np.where(illustrative_var == value)
                    plt.scatter(X_projected[selected, d1], X_projected[selected, d2], alpha=alpha, label=value, s=200)
                plt.legend()

            # affichage des labels des points
            if labels is not None:
                for i,(x,y) in enumerate(X_projected[:,[d1,d2]]):
                    if not str(labels[i]).isdigit():
                        plt.text(x, y, labels[i][:8],# je raccourcis le nom du pays
                              fontsize='12', ha='center',va='center') 
                    else:
                        plt.text(x, y, labels[i],
                              fontsize='12', ha='center',va='center') 
            # détermination des limites du graphique - je fixe les limites à la main pour avoir la même échelle entre la projection des centroïdes et des individus
            
            #boundary = np.max(np.abs(X_projected[:, [d1,d2]])) * 1.1
            #plt.xlim([-boundary,boundary])
            #plt.ylim([-boundary,boundary])
            lim=4*1.25
            plt.xlim([-lim,lim])
            plt.ylim([-lim,lim])
        
            # affichage des lignes horizontales et verticales
            plt.plot([-100, 100], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-100, 100], color='grey', ls='--')
            
            # appel de la fonction de tracé de cercle pour observer les variables qui sont dedans et en dehors.
            draw_circle()
            
            # nom des axes, avec le pourcentage d'inertie expliqué quand on a la variable pca
            if pca is None:
                plt.xlabel('F1')
                plt.ylabel('F2')
            else:
                plt.xlabel('F{} ({}%)'.format(d1+1, round(pca.eig_[1][d1],1)))
                plt.ylabel('F{} ({}%)'.format(d2+1, round(pca.eig_[2][d2],1)))
            
            if method is None:
                plt.title(f"Projection des {title_nb_of_indiv} {title_type} sur le 1er plan factoriel")         
            else:
                plt.title(f"Projection des {title_nb_of_indiv} {title_type} sur le 1er plan factoriel - Méthode {method}") 
                
            plt.legend(loc="upper right",title="Clusters", title_fontsize=16, fontsize=12)
            plt.savefig("img/Projections des "+title_type+'.png', dpi=200, bbox_inches="tight")
            plt.show(block=False)

# %%
def draw_circle():
    '''
    Tracé d'un cercle de diamètre 1
    '''
    theta = np.linspace(0, 2*np.pi, 100)
    plt.plot(np.cos(theta), np.sin(theta), color='grey', ls='--', lw=1 )  # Add a unit circle for scale

# %%
def build_clustermap(df,clustering_method,title=None):
    ''' 
    Method to build the clustermap
    Parameters : 
        - df = dataframe to plot
        - clustering method = the clustering method used
    '''
    df=df.groupby(clustering_method).agg('median')
    cm=sns.clustermap(df,standard_scale=1,cmap = 'Reds', figsize=(15,15))
    plt.setp(cm.ax_heatmap.get_yticklabels(), rotation=0)  
    plt.setp(cm.ax_heatmap.get_xticklabels(), rotation=70) 
    
    if title is None:
        plt.title("Clustermap sur " + clustering_method, loc="right", fontsize=30, pad=20)
        plt.savefig("img/Heatmap_"+clustering_method+".png", dpi=200, bbox_inches="tight")#, facecolor="white")
    else:
        plt.title("Clustermap sur " + title, loc="right", fontsize=30, pad=20)
        plt.savefig("img/Heatmap_"+title+".png", dpi=200, bbox_inches="tight")#, facecolor="white")
    plt.show()

# %%
def best_linkage_ach(data):
    '''
    Determines the best theoritical linkage method
    Parameters : 
     - the data centered and reduced
    '''

    methods = ['single' ,'complete' ,'average' ,'weighted' , 'centroid' ,'median' ,'ward' ]
    coef=[]
    for method in ((methods)) :
        Z = linkage(data, method=method,metric='euclidean')
        c, coph_dists = cophenet(Z, pdist(data))
        coef.append([method,c])
        plt.bar(method,c)
    plt.title("Coefficient cophénétique par type de lien")
    plt.show()

    coef_df = pd.DataFrame(coef, columns = ['Linkage type', 'Coef'])
    coef_max=max(coef_df.Coef)

    optimal_method=coef_df.loc[(coef_df["Coef"]==coef_max),'Linkage type'].item()
    print (f"La meilleure méthode théorique de lien est la '{optimal_method}'.")

# %% [markdown]
# # Les données

# %% [markdown]
# ## Analyse de la qualité des données

# %% [markdown]
# ### Nettoyage des données
#
# **Mode opératoire**<br>
# - Je me débarasse des lignes qui ne m'intéresse pas :
#     - Années autres que 2007 et 2017 pour la population
#     - Les données alimentaires qui n'ont pas de rapport avec la volaille
#     - Les éléments non utiles à l'analyse
# - Je recherche les colonnes qui ont une valeur unique, ou avec peu de valeurs distinctes pour en supprimer les colonnes.

# %%
population
# Out:
#      Code Domaine                       Domaine  Code zone         Zone  \
# 0              OA  Séries temporelles annuelles          2  Afghanistan
# 1              OA  Séries temporelles annuelles          2  Afghanistan
# 2              OA  Séries temporelles annuelles          2  Afghanistan
# 3              OA  Séries temporelles annuelles          2  Afghanistan
# 4              OA  Séries temporelles annuelles          2  Afghanistan
# ...           ...                           ...        ...          ...
# 4406           OA  Séries temporelles annuelles        181     Zimbabwe
# 4407           OA  Séries temporelles annuelles        181     Zimbabwe
# 4408           OA  Séries temporelles annuelles        181     Zimbabwe
# 4409           OA  Séries temporelles annuelles        181     Zimbabwe
# 4410           OA  Séries temporelles annuelles        181     Zimbabwe
#
#       Code Élément            Élément  Code Produit                 Produit  \
# 0              511  Population totale          3010  Population-Estimations
# 1              511  Population totale          3010  Population-Estimations
# 2              511  Population totale          3010  Population-Estimations
# 3              511  Population totale          3010  Population-Estimations
# 4              511  Population totale          3010  Population-Estimations
# ...            ...                ...           ...                     ...
# 4406           511  Population totale          3010  Population-Estimations
# 4407           511  Population totale          3010  Population-Estimations
# 4408           511  Population totale          3010  Population-Estimations
# 4409           511  Population totale          3010  Population-Estimations
# 4410           511  Population totale          3010  Population-Estimations
#
#       Code année  Année           Unité     Valeur Symbole  \
# 0           2000   2000  1000 personnes  20779.953       X
# 1           2001   2001  1000 personnes  21606.988       X
# 2           2002   2002  1000 personnes  22600.770       X
# 3           2003   2003  1000 personnes  23680.871       X
# 4           2004   2004  1000 personnes  24726.684       X
# ...          ...    ...             ...        ...     ...
# 4406        2014   2014  1000 personnes  13586.707       X
# 4407        2015   2015  1000 personnes  13814.629       X
# 4408        2016   2016  1000 personnes  14030.331       X
# 4409        2017   2017  1000 personnes  14236.595       X
# 4410        2018   2018  1000 personnes  14438.802       X
#
#              Description du Symbole Note
# 0     Sources internationales sûres  NaN
# 1     Sources internationales sûres  NaN
# 2     Sources internationales sûres  NaN
# 3     Sources internationales sûres  NaN
# 4     Sources internationales sûres  NaN
# ...                             ...  ...
# 4406  Sources internationales sûres  NaN
# 4407  Sources internationales sûres  NaN
# 4408  Sources internationales sûres  NaN
# 4409  Sources internationales sûres  NaN
# 4410  Sources internationales sûres  NaN
#
# [4411 rows x 15 columns]

# %%
food_avail
# Out:
#        Code Domaine                      Domaine  Code zone         Zone  \
# 0               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 1               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 2               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 3               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 4               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# ...             ...                          ...        ...          ...
# 176595          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176596          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176597          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176598          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176599          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
#
#         Code Élément  \
# 0               5511
# 1               5611
# 2               5072
# 3               5911
# 4               5301
# ...              ...
# 176595          5142
# 176596           645
# 176597           664
# 176598           674
# 176599           684
#
#                                                               Élément  \
# 0                                                          Production
# 1                                             Importations - Quantité
# 2                                                  Variation de stock
# 3                                             Exportations - Quantité
# 4                                            Disponibilité intérieure
# ...                                                               ...
# 176595                                                     Nourriture
# 176596         Disponibilité alimentaire en quantité (kg/personne/an)
# 176597                 Disponibilité alimentaire (Kcal/personne/jour)
# 176598       Disponibilité de protéines en quantité (g/personne/jour)
# 176599  Disponibilité de matière grasse en quantité (g/personne/jour)
#
#         Code Produit          Produit  Code année  Année               Unité  \
# 0               2511  Blé et produits        2017   2017  Milliers de tonnes
# 1               2511  Blé et produits        2017   2017  Milliers de tonnes
# 2               2511  Blé et produits        2017   2017  Milliers de tonnes
# 3               2511  Blé et produits        2017   2017  Milliers de tonnes
# 4               2511  Blé et produits        2017   2017  Milliers de tonnes
# ...              ...              ...         ...    ...                 ...
# 176595          2899     Miscellanees        2017   2017  Milliers de tonnes
# 176596          2899     Miscellanees        2017   2017                  kg
# 176597          2899     Miscellanees        2017   2017  Kcal/personne/jour
# 176598          2899     Miscellanees        2017   2017     g/personne/jour
# 176599          2899     Miscellanees        2017   2017     g/personne/jour
#
#          Valeur Symbole Description du Symbole
# 0       4281.00       S  Données standardisées
# 1       2302.00       S  Données standardisées
# 2       -119.00       S  Données standardisées
# 3          0.00       S  Données standardisées
# 4       6701.00       S  Données standardisées
# ...         ...     ...                    ...
# 176595    19.00       S  Données standardisées
# 176596     1.33      Fc        Donnée calculée
# 176597     1.00      Fc        Donnée calculée
# 176598     0.04      Fc        Donnée calculée
# 176599     0.02      Fc        Donnée calculée
#
# [176600 rows x 14 columns]

# %% [markdown]
# **Année autre que 2007 et 2017 - fichier population**<br>
# L'idée est de calculer l'évolution de la population sur 10 ans pour avoir une tendance du développement des pays.<br>
# Ca va me donner une information **Sociologique** sur la population.

# %%
evo_pop = population[(population["Année"]==2017) | (population["Année"]==2007)].copy()
evo_pop = evo_pop.loc[:,["Zone","Valeur", "Année","Code zone"]]
evo_pop=evo_pop.pivot_table(index=["Zone", "Code zone"],columns=["Année"], values="Valeur").reset_index().rename_axis(None, axis=1)

# %%
evo_pop
# Out:
#                           Zone  Code zone       2007       2017
# 0                  Afghanistan          2  27100.536  36296.113
# 1               Afrique du Sud        202  49119.759  57009.756
# 2                      Albanie          3   3033.998   2884.169
# 3                      Algérie          4  34166.972  41389.189
# 4                    Allemagne         79  81277.830  82658.409
# ..                         ...        ...        ...        ...
# 232               Îles Salomon         25    492.132    636.039
# 233    Îles Turques-et-Caïques        224     30.385     37.115
# 234   Îles Vierges américaines        240    107.115    104.751
# 235  Îles Vierges britanniques        239     25.047     29.577
# 236      Îles Wallis-et-Futuna        243     14.132     11.900
#
# [237 rows x 4 columns]

# %% [markdown]
# Je multiplie le résultat par 10 pour avoir le pourcentage moyen d'évolution par an sur les 10 ans

# %%
evo_pop["Evolution pop (%)"] = round(((evo_pop[2017]-evo_pop[2007]) / evo_pop[2007])*10,2)

# %% [markdown]
# J'ajoute la région de chaque pays au fichier

# %%
evo_pop=evo_pop.merge(region,how="left", left_on="Code zone", right_on="Code Pays")

# %%
evo_pop
# Out:
#                           Zone  Code zone       2007       2017  \
# 0                  Afghanistan          2  27100.536  36296.113
# 1               Afrique du Sud        202  49119.759  57009.756
# 2                      Albanie          3   3033.998   2884.169
# 3                      Algérie          4  34166.972  41389.189
# 4                    Allemagne         79  81277.830  82658.409
# ..                         ...        ...        ...        ...
# 232               Îles Salomon         25    492.132    636.039
# 233    Îles Turques-et-Caïques        224     30.385     37.115
# 234   Îles Vierges américaines        240    107.115    104.751
# 235  Îles Vierges britanniques        239     25.047     29.577
# 236      Îles Wallis-et-Futuna        243     14.132     11.900
#
#      Evolution pop (%)  Code Groupe de pays Groupe de pays  Code Pays  \
# 0                 3.39                 5300           Asie          2
# 1                 1.61                 5100        Afrique        202
# 2                -0.49                 5400         Europe          3
# 3                 2.11                 5100        Afrique          4
# 4                 0.17                 5400         Europe         79
# ..                 ...                  ...            ...        ...
# 232               2.92                 5500        Oc?anie         25
# 233               2.21                 5200      Am?riques        224
# 234              -0.22                 5200      Am?riques        240
# 235               1.81                 5200      Am?riques        239
# 236              -1.58                 5500        Oc?anie        243
#
#                           Pays  Code M49 Code ISO2 Code ISO3
# 0                  Afghanistan       4.0        AF       AFG
# 1               Afrique du Sud     710.0        ZA       ZAF
# 2                      Albanie       8.0        AL       ALB
# 3                      Alg?rie      12.0        DZ       DZA
# 4                    Allemagne     276.0        DE       DEU
# ..                         ...       ...       ...       ...
# 232               ?les Salomon      90.0        SB       SLB
# 233    ?les Turques-et-Ca?ques     796.0        TC       TCA
# 234   ?les Vierges am?ricaines     850.0        VI       VIR
# 235  ?les Vierges britanniques      92.0        VG       VGB
# 236      ?les Wallis-et-Futuna     876.0        WF       WLF
#
# [237 rows x 12 columns]

# %% [markdown]
# Je ne conserve que les colonnes qui m'intéressent

# %%
evo_pop=evo_pop.loc[:,["Zone","Evolution pop (%)", "Groupe de pays"]]

# %% [markdown]
# **Recherche des produits liés au poulet - fichier alimentation**
#
# La Viande de Volailles regroupe les différents produits suivants (source FAO : [Cultures et produits animaux](https://www.fao.org/faostat/fr/#data/TCL)) : <br>
# "Abats et foie de volaille", "Abats et foies de canard", "Abats et foies d'oie", "Foie gras, préparations", "Viande, canard", "Viande, dinde", "Viande, oie", "Viande, poulet en boîte", "Viande, volaille".<br>
# Comme nous n'avons pas de granularité au poulet dans les données de bilan alimentaire, on reste sur le cas général Viande de Volailles.

# %%
produit = food_avail["Produit"].str.lower()
mask = np.column_stack([produit.str.contains(r"volaille|poule", na=False)])
poultry_meat=food_avail.loc[mask.any(axis=1)].copy()

# %%
poultry_meat.sample(5)
# Out:
#        Code Domaine                      Domaine  Code zone  \
# 16491           FBS  Nouveaux Bilans Alimentaire         14
# 62530           FBS  Nouveaux Bilans Alimentaire         74
# 139920          FBS  Nouveaux Bilans Alimentaire        215
# 158198          FBS  Nouveaux Bilans Alimentaire        207
# 23933           FBS  Nouveaux Bilans Alimentaire         20
#
#                                Zone  Code Élément  \
# 16491                       Barbade          5911
# 62530                         Gabon          5911
# 139920  République-Unie de Tanzanie          5171
# 158198                     Suriname          5142
# 23933                      Botswana          5301
#
#                             Élément  Code Produit              Produit  \
# 16491       Exportations - Quantité          2734  Viande de Volailles
# 62530       Exportations - Quantité          2734  Viande de Volailles
# 139920  Alimentation pour touristes          2734  Viande de Volailles
# 158198                   Nourriture          2734  Viande de Volailles
# 23933      Disponibilité intérieure          2734  Viande de Volailles
#
#         Code année  Année               Unité  Valeur Symbole  \
# 16491         2017   2017  Milliers de tonnes     0.0       S
# 62530         2017   2017  Milliers de tonnes     0.0       S
# 139920        2017   2017  Milliers de tonnes     0.0       S
# 158198        2017   2017  Milliers de tonnes    18.0       S
# 23933         2017   2017  Milliers de tonnes     7.0       S
#
#        Description du Symbole
# 16491   Données standardisées
# 62530   Données standardisées
# 139920  Données standardisées
# 158198  Données standardisées
# 23933   Données standardisées

# %%
print (f"""Avant modification, le fichier population contenait {population.shape[0]} lignes et {population.shape[1]} colonnes.
Maintenant, le fichier contient {evo_pop.shape[0]} lignes et {evo_pop.shape[1]} colonnes.

Le fichier alimentation était composé de {food_avail.shape[0]} lignes et {food_avail.shape[1]} colonnes.
Il est maintenant constitué de {poultry_meat.shape[0]} lignes et {poultry_meat.shape[1]} colonnes.""")
# Out:
# Avant modification, le fichier population contenait 4411 lignes et 15 colonnes.
# Maintenant, le fichier contient 237 lignes et 3 colonnes.
#
# Le fichier alimentation était composé de 176600 lignes et 14 colonnes.
# Il est maintenant constitué de 2061 lignes et 14 colonnes.

# %% [markdown]
# Je transpose mon fichier poultry_meat pour avoir les pays en index, et les éléments en colonnes.

# %%
poultry_meat=poultry_meat.pivot(values="Valeur",index="Zone",columns="Élément")\
.reset_index()\
.rename(columns={'Disponibilité intérieure':'Dispo int. volaille','Disponibilité alimentaire (Kcal/personne/jour)': 'Dispo énerg. volaille (kcal/pers/jour)',\
                 'Disponibilité de protéines en quantité (g/personne/jour)': 'Dispo prot volaille(g/pers/jour)','Exportations - Quantité' : 'Exportation de volaille',\
                 'Importations - Quantité' : 'Importation de volaille', 'Nourriture' : 'Nourriture de volaille', 'Production' : 'Production de volaille',\
                 'Alimentation pour touristes':'Alimentation de volaille pour touristes', 'Variation de stock' : 'Variation de stock volaille',\
                 'Pertes' :'Pertes volaille','Résidus':'Résidus volaille', 'Traitement':'Traitement volaille','Autres utilisations (non alimentaire)':'Autres utilisations (non alimentaire) volaille'})\
.rename_axis(None, axis=1) # rename_axis to delete the name of the index that is "Élément" after pivot

# %% [markdown]
# Je regarde s'il y a des valeurs nulles

# %%
poultry_meat.isnull().sum()
# Out:
# Zone                                                               0
# Alimentation de volaille pour touristes                           94
# Aliments pour animaux                                            171
# Autres utilisations (non alimentaire) volaille                   138
# Dispo énerg. volaille (kcal/pers/jour)                             0
# Disponibilité alimentaire en quantité (kg/personne/an)             0
# Disponibilité de matière grasse en quantité (g/personne/jour)      0
# Dispo prot volaille(g/pers/jour)                                   0
# Dispo int. volaille                                                2
# Exportation de volaille                                           37
# Importation de volaille                                            2
# Nourriture de volaille                                             2
# Pertes volaille                                                  105
# Production de volaille                                             4
# Résidus volaille                                                   8
# Semences                                                         171
# Traitement volaille                                              126
# Variation de stock volaille                                        3
# dtype: int64

# %% [markdown]
# Je supprime les 2 colonnes qui n'ont que des valeurs nulles, 'Semences' et 'Aliments pour animaux', ainsi que :
# - 'Dispo énerg. volaille (kcal/pers/jour)'
# - 'Disponibilité alimentaire en quantité (kg/personne/an)'
# - 'Disponibilité de matière grasse en quantité (g/personne/jour)'>

# %%
poultry_meat.drop(columns=['Disponibilité alimentaire en quantité (kg/personne/an)','Dispo énerg. volaille (kcal/pers/jour)',\
                           'Disponibilité de matière grasse en quantité (g/personne/jour)','Aliments pour animaux', 'Semences'], inplace=True)
#'Disponibilité intérieure','''
#'Variation de stock','Pertes', 'Résidus', 'Disponibilité de matière grasse en quantité (g/personne/jour)','Traitement', 'Autres utilisations (non alimentaire)','Aliments pour animaux', 'Semences']

# %%
poultry_meat#.rename_axis(None, axis=1)
# Out:
#                       Zone  Alimentation de volaille pour touristes  \
# 0              Afghanistan                                      NaN
# 1           Afrique du Sud                                      0.0
# 2                  Albanie                                      NaN
# 3                  Algérie                                      0.0
# 4                Allemagne                                      NaN
# ..                     ...                                      ...
# 167    Émirats arabes unis                                      NaN
# 168               Équateur                                      0.0
# 169  États-Unis d'Amérique                                      NaN
# 170               Éthiopie                                      0.0
# 171           Îles Salomon                                     -0.0
#
#      Autres utilisations (non alimentaire) volaille  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 167                                             NaN
# 168                                             NaN
# 169                                            89.0
# 170                                             NaN
# 171                                             NaN
#
#      Dispo prot volaille(g/pers/jour)  Dispo int. volaille  \
# 0                                0.54                 57.0
# 1                               14.11               2118.0
# 2                                6.26                 47.0
# 3                                1.97                277.0
# 4                                7.96               1739.0
# ..                                ...                  ...
# 167                             14.80                412.0
# 168                              6.15                341.0
# 169                             19.93              18266.0
# 170                              0.04                 14.0
# 171                              1.51                  3.0
#
#      Exportation de volaille  Importation de volaille  Nourriture de volaille  \
# 0                        NaN                     29.0                    55.0
# 1                       63.0                    514.0                  2035.0
# 2                        0.0                     38.0                    47.0
# 3                        0.0                      2.0                   264.0
# 4                      646.0                    842.0                  1609.0
# ..                       ...                      ...                     ...
# 167                     94.0                    433.0                   412.0
# 168                      0.0                      0.0                   324.0
# 169                   3692.0                    123.0                 18100.0
# 170                      NaN                      1.0                    14.0
# 171                      0.0                      6.0                     3.0
#
#      Pertes volaille  Production de volaille  Résidus volaille  \
# 0                2.0                    28.0               0.0
# 1               83.0                  1667.0               0.0
# 2                NaN                    13.0               0.0
# 3               13.0                   275.0               0.0
# 4                NaN                  1514.0             -38.0
# ..               ...                     ...               ...
# 167              NaN                    48.0              -0.0
# 168             17.0                   340.0               0.0
# 169              NaN                 21914.0              -0.0
# 170              1.0                    14.0               0.0
# 171              NaN                     0.0               0.0
#
#      Traitement volaille  Variation de stock volaille
# 0                    NaN                          0.0
# 1                    NaN                         -0.0
# 2                    NaN                          4.0
# 3                    NaN                          0.0
# 4                  167.0                        -29.0
# ..                   ...                          ...
# 167                  NaN                        -26.0
# 168                  NaN                         -1.0
# 169                 77.0                         80.0
# 170                  NaN                          0.0
# 171                  NaN                          3.0
#
# [172 rows x 13 columns]

# %% [markdown]
# Pour ne pas me gêner dans les calculs, je remplace les valeurs Nan par des 0 : lorsque la valeur n'est pas présente, je n'additionnerai rien, donc 0.

# %%
poultry_meat=poultry_meat.fillna(0)

# %% [markdown]
# ### Type des données

# %%
evo_pop.dtypes
# Out:
# Zone                  object
# Evolution pop (%)    float64
# Groupe de pays        object
# dtype: object

# %%
poultry_meat.dtypes
# Out:
# Zone                                               object
# Alimentation de volaille pour touristes           float64
# Autres utilisations (non alimentaire) volaille    float64
# Dispo prot volaille(g/pers/jour)                  float64
# Dispo int. volaille                               float64
# Exportation de volaille                           float64
# Importation de volaille                           float64
# Nourriture de volaille                            float64
# Pertes volaille                                   float64
# Production de volaille                            float64
# Résidus volaille                                  float64
# Traitement volaille                               float64
# Variation de stock volaille                       float64
# dtype: object

# %% [markdown]
# ### Valeurs manquantes ou nulles

# %%
evo_pop.isnull().sum()
# Out:
# Zone                 0
# Evolution pop (%)    8
# Groupe de pays       0
# dtype: int64

# %%
poultry_meat.isnull().sum()
# Out:
# Zone                                              0
# Alimentation de volaille pour touristes           0
# Autres utilisations (non alimentaire) volaille    0
# Dispo prot volaille(g/pers/jour)                  0
# Dispo int. volaille                               0
# Exportation de volaille                           0
# Importation de volaille                           0
# Nourriture de volaille                            0
# Pertes volaille                                   0
# Production de volaille                            0
# Résidus volaille                                  0
# Traitement volaille                               0
# Variation de stock volaille                       0
# dtype: int64

# %% [markdown]
# ### Recherche d'anomalies

# %%
evo_pop.describe()
# Out:
#        Evolution pop (%)
# count         229.000000
# mean            1.459738
# std             1.655737
# min            -1.580000
# 25%             0.340000
# 50%             1.190000
# 75%             2.390000
# max            12.360000

# %%
poultry_meat.describe()
# Out:
#        Alimentation de volaille pour touristes  \
# count                               172.000000
# mean                                  0.098837
# std                                   1.613756
# min                                 -18.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   5.000000
#
#        Autres utilisations (non alimentaire) volaille  \
# count                                      172.000000
# mean                                         8.720930
# std                                         65.004391
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                        783.000000
#
#        Dispo prot volaille(g/pers/jour)  Dispo int. volaille  \
# count                        172.000000           172.000000
# mean                           7.121279           679.598837
# std                            5.603464          2175.612987
# min                            0.040000             0.000000
# 25%                            2.165000            28.750000
# 50%                            6.505000            98.000000
# 75%                           10.365000           360.750000
# max                           27.870000         18266.000000
#
#        Exportation de volaille  Importation de volaille  \
# count               172.000000               172.000000
# mean                103.750000                88.488372
# std                 458.066125               185.824620
# min                   0.000000                 0.000000
# 25%                   0.000000                 3.000000
# 50%                   0.000000                16.000000
# 75%                  12.000000                79.750000
# max                4223.000000              1069.000000
#
#        Nourriture de volaille  Pertes volaille  Production de volaille  \
# count              172.000000       172.000000              172.000000
# mean               649.406977        16.976744              708.325581
# std               2125.189092        78.027657             2474.456332
# min                  0.000000         0.000000                0.000000
# 25%                 27.500000         0.000000               11.000000
# 50%                 94.500000         0.000000               66.000000
# 75%                353.750000         2.000000              368.750000
# max              18100.000000       695.000000            21914.000000
#
#        Résidus volaille  Traitement volaille  Variation de stock volaille
# count        172.000000           172.000000                   172.000000
# mean          -2.703488             7.029070                    13.430233
# std           13.271761            30.541397                    74.722417
# min         -125.000000             0.000000                  -119.000000
# 25%            0.000000             0.000000                     0.000000
# 50%            0.000000             0.000000                     0.000000
# 75%            0.000000             0.000000                     7.000000
# max            0.000000           306.000000                   859.000000

# %% [markdown]
# ## Ajout de nouvelles données

# %% [markdown]
# ### Calcul de données
#
# On somme la totalité des informations pour pouvoir comparer les données volailles à la totalité des aliments.

# %%
food_avail
# Out:
#        Code Domaine                      Domaine  Code zone         Zone  \
# 0               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 1               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 2               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 3               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 4               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# ...             ...                          ...        ...          ...
# 176595          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176596          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176597          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176598          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176599          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
#
#         Code Élément  \
# 0               5511
# 1               5611
# 2               5072
# 3               5911
# 4               5301
# ...              ...
# 176595          5142
# 176596           645
# 176597           664
# 176598           674
# 176599           684
#
#                                                               Élément  \
# 0                                                          Production
# 1                                             Importations - Quantité
# 2                                                  Variation de stock
# 3                                             Exportations - Quantité
# 4                                            Disponibilité intérieure
# ...                                                               ...
# 176595                                                     Nourriture
# 176596         Disponibilité alimentaire en quantité (kg/personne/an)
# 176597                 Disponibilité alimentaire (Kcal/personne/jour)
# 176598       Disponibilité de protéines en quantité (g/personne/jour)
# 176599  Disponibilité de matière grasse en quantité (g/personne/jour)
#
#         Code Produit          Produit  Code année  Année               Unité  \
# 0               2511  Blé et produits        2017   2017  Milliers de tonnes
# 1               2511  Blé et produits        2017   2017  Milliers de tonnes
# 2               2511  Blé et produits        2017   2017  Milliers de tonnes
# 3               2511  Blé et produits        2017   2017  Milliers de tonnes
# 4               2511  Blé et produits        2017   2017  Milliers de tonnes
# ...              ...              ...         ...    ...                 ...
# 176595          2899     Miscellanees        2017   2017  Milliers de tonnes
# 176596          2899     Miscellanees        2017   2017                  kg
# 176597          2899     Miscellanees        2017   2017  Kcal/personne/jour
# 176598          2899     Miscellanees        2017   2017     g/personne/jour
# 176599          2899     Miscellanees        2017   2017     g/personne/jour
#
#          Valeur Symbole Description du Symbole
# 0       4281.00       S  Données standardisées
# 1       2302.00       S  Données standardisées
# 2       -119.00       S  Données standardisées
# 3          0.00       S  Données standardisées
# 4       6701.00       S  Données standardisées
# ...         ...     ...                    ...
# 176595    19.00       S  Données standardisées
# 176596     1.33      Fc        Donnée calculée
# 176597     1.00      Fc        Donnée calculée
# 176598     0.04      Fc        Donnée calculée
# 176599     0.02      Fc        Donnée calculée
#
# [176600 rows x 14 columns]

# %%
food_avail_total=food_avail.copy()
food_avail_total=food_avail_total.pivot_table(index="Zone",columns="Élément", values="Valeur",aggfunc=np.sum)\
.reset_index().rename(columns={'Disponibilité de protéines en quantité (g/personne/jour)': 'Dispo prot. totale (g/pers/jour)'}).rename_axis(None, axis=1)

# %%
food_avail_total=food_avail_total.loc[:,['Zone','Dispo prot. totale (g/pers/jour)']]
food_avail_total
# Out:
#                       Zone  Dispo prot. totale (g/pers/jour)
# 0              Afghanistan                             54.09
# 1           Afrique du Sud                             83.36
# 2                  Albanie                            119.50
# 3                  Algérie                             92.85
# 4                Allemagne                            104.07
# ..                     ...                               ...
# 169    Émirats arabes unis                            107.26
# 170               Équateur                             65.77
# 171  États-Unis d'Amérique                            113.61
# 172               Éthiopie                             65.64
# 173           Îles Salomon                             53.64
#
# [174 rows x 2 columns]

# %% [markdown]
# ### Données Politiques et Economiques et autres
#
# - Fichier political_stability - Récupération de la stabilité politique - moyenne années 2007 à 2017 : Dimension **Politique**.<br>
# - Fichier additional_info
#     - Récupération du PIB en US$ par pays - année 2017 : Dimension **Economique**.<br>
#     - Part de protéines animales par pays.<br>

# %%
political_stability=pd.read_excel(path+"Stabilite_Politique_2007-2017.xlsx")
political_stability
# Out:
#                                  Domaine         Zone Élément  \
# 0     Données de la sécurité alimentaire  Afghanistan  Valeur
# 1     Données de la sécurité alimentaire  Afghanistan  Valeur
# 2     Données de la sécurité alimentaire  Afghanistan  Valeur
# 3     Données de la sécurité alimentaire  Afghanistan  Valeur
# 4     Données de la sécurité alimentaire  Afghanistan  Valeur
# ...                                  ...          ...     ...
# 2239  Données de la sécurité alimentaire     Zimbabwe  Valeur
# 2240  Données de la sécurité alimentaire     Zimbabwe  Valeur
# 2241  Données de la sécurité alimentaire     Zimbabwe  Valeur
# 2242  Données de la sécurité alimentaire     Zimbabwe  Valeur
# 2243  Données de la sécurité alimentaire     Zimbabwe  Valeur
#
#                                                              Produit  Année  \
# 0     Stabilité politique et absence de violence/terrorisme (indice)   2007
# 1     Stabilité politique et absence de violence/terrorisme (indice)   2008
# 2     Stabilité politique et absence de violence/terrorisme (indice)   2009
# 3     Stabilité politique et absence de violence/terrorisme (indice)   2010
# 4     Stabilité politique et absence de violence/terrorisme (indice)   2011
# ...                                                              ...    ...
# 2239  Stabilité politique et absence de violence/terrorisme (indice)   2013
# 2240  Stabilité politique et absence de violence/terrorisme (indice)   2014
# 2241  Stabilité politique et absence de violence/terrorisme (indice)   2015
# 2242  Stabilité politique et absence de violence/terrorisme (indice)   2016
# 2243  Stabilité politique et absence de violence/terrorisme (indice)   2017
#
#       Valeur
# 0      -2.41
# 1      -2.69
# 2      -2.71
# 3      -2.58
# 4      -2.50
# ...      ...
# 2239   -0.67
# 2240   -0.71
# 2241   -0.62
# 2242   -0.62
# 2243   -0.71
#
# [2244 rows x 6 columns]

# %%
political_stability.drop(columns=["Domaine","Élément","Produit"], inplace=True)

# %%
political_stability=political_stability.groupby(["Zone"], as_index=False).agg({"Valeur":'mean'})
political_stability.rename(columns={"Valeur":"Stabilité politique"}, inplace=True)
political_stability["Stabilité politique"]=round(political_stability["Stabilité politique"],2)
political_stability
# Out:
#                       Zone  Stabilité politique
# 0              Afghanistan                -2.57
# 1           Afrique du Sud                -0.06
# 2                  Albanie                 0.07
# 3                  Algérie                -1.17
# 4                Allemagne                 0.82
# ..                     ...                  ...
# 199  États-Unis d'Amérique                 0.52
# 200               Éthiopie                -1.58
# 201              Îles Cook                 1.23
# 202          Îles Marshall                 0.98
# 203           Îles Salomon                 0.33
#
# [204 rows x 2 columns]

# %%
additional_info=pd.read_excel(path+"Infos complementaires.xlsx")

# %%
additional_info
# Out:
#     Code Domaine                             Domaine  Code zone (FAO)  \
# 0             FS  Données de la sécurité alimentaire                2
# 1             FS  Données de la sécurité alimentaire                2
# 2             FS  Données de la sécurité alimentaire              202
# 3             FS  Données de la sécurité alimentaire              202
# 4             FS  Données de la sécurité alimentaire                3
# ..           ...                                 ...              ...
# 403           FS  Données de la sécurité alimentaire              249
# 404           FS  Données de la sécurité alimentaire              251
# 405           FS  Données de la sécurité alimentaire              251
# 406           FS  Données de la sécurité alimentaire              181
# 407           FS  Données de la sécurité alimentaire              181
#
#                Zone  Code Élément Élément  Code Produit  \
# 0       Afghanistan          6123  Valeur         21014
# 1       Afghanistan          6126  Valeur         22013
# 2    Afrique du Sud          6123  Valeur         21014
# 3    Afrique du Sud          6126  Valeur         22013
# 4           Albanie          6123  Valeur         21014
# ..              ...           ...     ...           ...
# 403           Yémen          6126  Valeur         22013
# 404          Zambie          6123  Valeur         21014
# 405          Zambie          6126  Valeur         22013
# 406        Zimbabwe          6123  Valeur         21014
# 407        Zimbabwe          6126  Valeur         22013
#
#                                                                                        Produit  \
# 0    Disponibilités protéines moyennes d’origine animale (g/personne/jour) (moyenne sur 3 ans)
# 1                                   PIB par habitant, ($ PPA internationaux constants de 2017)
# 2    Disponibilités protéines moyennes d’origine animale (g/personne/jour) (moyenne sur 3 ans)
# 3                                   PIB par habitant, ($ PPA internationaux constants de 2017)
# 4    Disponibilités protéines moyennes d’origine animale (g/personne/jour) (moyenne sur 3 ans)
# ..                                                                                         ...
# 403                                 PIB par habitant, ($ PPA internationaux constants de 2017)
# 404  Disponibilités protéines moyennes d’origine animale (g/personne/jour) (moyenne sur 3 ans)
# 405                                 PIB par habitant, ($ PPA internationaux constants de 2017)
# 406  Disponibilités protéines moyennes d’origine animale (g/personne/jour) (moyenne sur 3 ans)
# 407                                 PIB par habitant, ($ PPA internationaux constants de 2017)
#
#      Code année      Année   Valeur
# 0      20162018  2016-2018     10.7
# 1          2017       2017   2058.4
# 2      20162018  2016-2018     35.7
# 3          2017       2017  13860.3
# 4      20162018  2016-2018     61.0
# ..          ...        ...      ...
# 403        2017       2017   2300.0
# 404    20162018  2016-2018     13.7
# 405        2017       2017   3485.0
# 406    20162018  2016-2018      NaN
# 407        2017       2017   3795.6
#
# [408 rows x 11 columns]

# %%
additional_info=additional_info.pivot_table(index="Zone",columns="Produit", values="Valeur")\
.reset_index()\
.rename(columns={"Disponibilités protéines moyennes d’origine animale (g/personne/jour) (moyenne sur 3 ans)": "Dispo prot. animale (g/pers/jour)",\
        "PIB par habitant, ($ PPA internationaux constants de 2017)" : "PIB par hab.",\
        })\
.rename_axis(None, axis=1)

# %%
additional_info
# Out:
#                       Zone  Dispo prot. animale (g/pers/jour)  PIB par hab.
# 0              Afghanistan                               10.7        2058.4
# 1           Afrique du Sud                               35.7       13860.3
# 2                  Albanie                               61.0       12771.0
# 3                  Algérie                               25.0       11737.4
# 4                Allemagne                               63.0       53071.5
# ..                     ...                                ...           ...
# 190               Équateur                               30.7       11617.9
# 191  États-Unis d'Amérique                               73.0       59914.8
# 192               Éthiopie                                6.0        2021.6
# 193          Îles Marshall                                NaN        3711.4
# 194           Îles Salomon                               15.3        2663.5
#
# [195 rows x 3 columns]

# %% [markdown]
# ## Fusion des différents fichiers
#
# On a 5 dataframes à ce stade :
# - evo_pop
# - poultry_meat
# - food_avail_total
# - additional_info
# - political_stability

# %%
file_list = [evo_pop,poultry_meat,food_avail_total,additional_info, political_stability]
names_list = ["evo_pop","poultry_meat","food_avail_total","additional_info","political_stability"]

# %%
for var, name in zip(file_list, names_list):
    print (f"Le fichier {name} contient {var.shape[0]} lignes")
# Out:
# Le fichier evo_pop contient 237 lignes
# Le fichier poultry_meat contient 172 lignes
# Le fichier food_avail_total contient 174 lignes
# Le fichier additional_info contient 195 lignes
# Le fichier political_stability contient 204 lignes

# %% [markdown]
# **Observation**<br>
# Le fichier qui nous intéresse est celui qui contient des données sur la volaille. On va  faire une jointure gauche sur ce fichier pour garder toutes ses lignes.

# %%
temp_df=poultry_meat.merge(evo_pop,how="left")

# %%
temp_df=temp_df.merge(food_avail_total,how="left")

# %%
temp_df=temp_df.merge(additional_info, how="left")

# %%
temp_df=temp_df.merge(political_stability, how="left")

# %%
temp_df.set_index('Zone', inplace=True)
temp_df
# Out:
#                        Alimentation de volaille pour touristes  \
# Zone
# Afghanistan                                                0.0
# Afrique du Sud                                             0.0
# Albanie                                                    0.0
# Algérie                                                    0.0
# Allemagne                                                  0.0
# ...                                                        ...
# Émirats arabes unis                                        0.0
# Équateur                                                   0.0
# États-Unis d'Amérique                                      0.0
# Éthiopie                                                   0.0
# Îles Salomon                                              -0.0
#
#                        Autres utilisations (non alimentaire) volaille  \
# Zone
# Afghanistan                                                       0.0
# Afrique du Sud                                                    0.0
# Albanie                                                           0.0
# Algérie                                                           0.0
# Allemagne                                                         0.0
# ...                                                               ...
# Émirats arabes unis                                               0.0
# Équateur                                                          0.0
# États-Unis d'Amérique                                            89.0
# Éthiopie                                                          0.0
# Îles Salomon                                                      0.0
#
#                        Dispo prot volaille(g/pers/jour)  Dispo int. volaille  \
# Zone
# Afghanistan                                        0.54                 57.0
# Afrique du Sud                                    14.11               2118.0
# Albanie                                            6.26                 47.0
# Algérie                                            1.97                277.0
# Allemagne                                          7.96               1739.0
# ...                                                 ...                  ...
# Émirats arabes unis                               14.80                412.0
# Équateur                                           6.15                341.0
# États-Unis d'Amérique                             19.93              18266.0
# Éthiopie                                           0.04                 14.0
# Îles Salomon                                       1.51                  3.0
#
#                        Exportation de volaille  Importation de volaille  \
# Zone
# Afghanistan                                0.0                     29.0
# Afrique du Sud                            63.0                    514.0
# Albanie                                    0.0                     38.0
# Algérie                                    0.0                      2.0
# Allemagne                                646.0                    842.0
# ...                                        ...                      ...
# Émirats arabes unis                       94.0                    433.0
# Équateur                                   0.0                      0.0
# États-Unis d'Amérique                   3692.0                    123.0
# Éthiopie                                   0.0                      1.0
# Îles Salomon                               0.0                      6.0
#
#                        Nourriture de volaille  Pertes volaille  \
# Zone
# Afghanistan                              55.0              2.0
# Afrique du Sud                         2035.0             83.0
# Albanie                                  47.0              0.0
# Algérie                                 264.0             13.0
# Allemagne                              1609.0              0.0
# ...                                       ...              ...
# Émirats arabes unis                     412.0              0.0
# Équateur                                324.0             17.0
# États-Unis d'Amérique                 18100.0              0.0
# Éthiopie                                 14.0              1.0
# Îles Salomon                              3.0              0.0
#
#                        Production de volaille  Résidus volaille  \
# Zone
# Afghanistan                              28.0               0.0
# Afrique du Sud                         1667.0               0.0
# Albanie                                  13.0               0.0
# Algérie                                 275.0               0.0
# Allemagne                              1514.0             -38.0
# ...                                       ...               ...
# Émirats arabes unis                      48.0              -0.0
# Équateur                                340.0               0.0
# États-Unis d'Amérique                 21914.0              -0.0
# Éthiopie                                 14.0               0.0
# Îles Salomon                              0.0               0.0
#
#                        Traitement volaille  Variation de stock volaille  \
# Zone
# Afghanistan                            0.0                          0.0
# Afrique du Sud                         0.0                         -0.0
# Albanie                                0.0                          4.0
# Algérie                                0.0                          0.0
# Allemagne                            167.0                        -29.0
# ...                                    ...                          ...
# Émirats arabes unis                    0.0                        -26.0
# Équateur                               0.0                         -1.0
# États-Unis d'Amérique                 77.0                         80.0
# Éthiopie                               0.0                          0.0
# Îles Salomon                           0.0                          3.0
#
#                        Evolution pop (%) Groupe de pays  \
# Zone
# Afghanistan                         3.39           Asie
# Afrique du Sud                      1.61        Afrique
# Albanie                            -0.49         Europe
# Algérie                             2.11        Afrique
# Allemagne                           0.17         Europe
# ...                                  ...            ...
# Émirats arabes unis                 5.38           Asie
# Équateur                            1.74      Am?riques
# États-Unis d'Amérique               0.81      Am?riques
# Éthiopie                            3.19        Afrique
# Îles Salomon                        2.92        Oc?anie
#
#                        Dispo prot. totale (g/pers/jour)  \
# Zone
# Afghanistan                                       54.09
# Afrique du Sud                                    83.36
# Albanie                                          119.50
# Algérie                                           92.85
# Allemagne                                        104.07
# ...                                                 ...
# Émirats arabes unis                              107.26
# Équateur                                          65.77
# États-Unis d'Amérique                            113.61
# Éthiopie                                          65.64
# Îles Salomon                                      53.64
#
#                        Dispo prot. animale (g/pers/jour)  PIB par hab.  \
# Zone
# Afghanistan                                         10.7        2058.4
# Afrique du Sud                                      35.7       13860.3
# Albanie                                             61.0       12771.0
# Algérie                                             25.0       11737.4
# Allemagne                                           63.0       53071.5
# ...                                                  ...           ...
# Émirats arabes unis                                 34.4       67183.6
# Équateur                                            30.7       11617.9
# États-Unis d'Amérique                               73.0       59914.8
# Éthiopie                                             6.0        2021.6
# Îles Salomon                                        15.3        2663.5
#
#                        Stabilité politique
# Zone
# Afghanistan                          -2.57
# Afrique du Sud                       -0.06
# Albanie                               0.07
# Algérie                              -1.17
# Allemagne                             0.82
# ...                                    ...
# Émirats arabes unis                   0.80
# Équateur                             -0.41
# États-Unis d'Amérique                 0.52
# Éthiopie                             -1.58
# Îles Salomon                          0.33
#
# [172 rows x 18 columns]

# %% [markdown]
# ### Imputation des valeurs nulles
#
# Après observation des résultats, je vais voir si je peux trouver les informations sur Internet. <br>
# Le PIB a été récupéré [ici](https://fr.wikipedia.org/wiki/Liste_des_pays_par_PIB_(PPA)_par_habitant) pour
# Taiwan, Cuba, Nouvelle-Calédonie, Polynésie française, République populaire démocratique de Corée, Venezuela (République bolivarienne du), Yémen.<br>
# Le reste des valeurs manquantes sera remplacée par la vameur des voisins proches.

# %%
# Preview of Nan values before deletion
nanValues=temp_df[temp_df.isna().any(axis=1)]

print (f""" Il y a {len(nanValues)} pays sur les {len(temp_df)} de notre tableau qui ont des valeurs nulles.
""")
nanValues
# Out:
#  Il y a 13 pays sur les 172 de notre tableau qui ont des valeurs nulles.
#                       Alimentation de volaille pour touristes  \
# Zone
# Antigua-et-Barbuda                                        2.0
# Bahamas                                                   0.0
# Grenade                                                   3.0
# Guinée                                                    0.0
# Maldives                                                  5.0
# Mozambique                                                0.0
# Nouvelle-Calédonie                                        0.0
# Ouganda                                                   0.0
# Polynésie française                                       2.0
# Saint-Kitts-et-Nevis                                      1.0
# Sainte-Lucie                                              0.0
# Soudan                                                    0.0
# Zimbabwe                                                  0.0
#
#                       Autres utilisations (non alimentaire) volaille  \
# Zone
# Antigua-et-Barbuda                                               0.0
# Bahamas                                                          9.0
# Grenade                                                          0.0
# Guinée                                                           0.0
# Maldives                                                         0.0
# Mozambique                                                       0.0
# Nouvelle-Calédonie                                               0.0
# Ouganda                                                          0.0
# Polynésie française                                              0.0
# Saint-Kitts-et-Nevis                                             0.0
# Sainte-Lucie                                                     0.0
# Soudan                                                           0.0
# Zimbabwe                                                         0.0
#
#                       Dispo prot volaille(g/pers/jour)  Dispo int. volaille  \
# Zone
# Antigua-et-Barbuda                               17.77                  7.0
# Bahamas                                          14.61                 26.0
# Grenade                                          15.50                  8.0
# Guinée                                            1.42                 50.0
# Maldives                                          4.70                 12.0
# Mozambique                                        1.20                116.0
# Nouvelle-Calédonie                               14.05                 11.0
# Ouganda                                           0.51                 66.0
# Polynésie française                              16.20                 15.0
# Saint-Kitts-et-Nevis                             19.22                  4.0
# Sainte-Lucie                                     19.00                 11.0
# Soudan                                            0.54                 69.0
# Zimbabwe                                          1.59                 76.0
#
#                       Exportation de volaille  Importation de volaille  \
# Zone
# Antigua-et-Barbuda                        0.0                      7.0
# Bahamas                                   0.0                     24.0
# Grenade                                   0.0                      7.0
# Guinée                                    0.0                     37.0
# Maldives                                  0.0                     12.0
# Mozambique                                0.0                     24.0
# Nouvelle-Calédonie                        0.0                      9.0
# Ouganda                                   0.0                      0.0
# Polynésie française                       0.0                     15.0
# Saint-Kitts-et-Nevis                      0.0                      4.0
# Sainte-Lucie                              0.0                     10.0
# Soudan                                    0.0                      2.0
# Zimbabwe                                  0.0                      6.0
#
#                       Nourriture de volaille  Pertes volaille  \
# Zone
# Antigua-et-Barbuda                       5.0              0.0
# Bahamas                                 16.0              0.0
# Grenade                                  5.0              0.0
# Guinée                                  49.0              1.0
# Maldives                                 7.0              0.0
# Mozambique                             103.0              4.0
# Nouvelle-Calédonie                      11.0              0.0
# Ouganda                                 62.0              3.0
# Polynésie française                     13.0              0.0
# Saint-Kitts-et-Nevis                     3.0              0.0
# Sainte-Lucie                            10.0              0.0
# Soudan                                  65.0              3.0
# Zimbabwe                                67.0              3.0
#
#                       Production de volaille  Résidus volaille  \
# Zone
# Antigua-et-Barbuda                       0.0               0.0
# Bahamas                                  6.0               0.0
# Grenade                                  1.0              -0.0
# Guinée                                  13.0               0.0
# Maldives                                 0.0               0.0
# Mozambique                              92.0               0.0
# Nouvelle-Calédonie                       1.0               0.0
# Ouganda                                 65.0               0.0
# Polynésie française                      1.0               0.0
# Saint-Kitts-et-Nevis                     0.0               0.0
# Sainte-Lucie                             1.0               0.0
# Soudan                                  67.0               0.0
# Zimbabwe                                69.0               0.0
#
#                       Traitement volaille  Variation de stock volaille  \
# Zone
# Antigua-et-Barbuda                    0.0                          0.0
# Bahamas                               0.0                          4.0
# Grenade                               0.0                         -0.0
# Guinée                                0.0                         -0.0
# Maldives                              0.0                          0.0
# Mozambique                            9.0                         -1.0
# Nouvelle-Calédonie                    0.0                         -1.0
# Ouganda                               0.0                         -0.0
# Polynésie française                   0.0                          0.0
# Saint-Kitts-et-Nevis                  0.0                          0.0
# Sainte-Lucie                          0.0                          0.0
# Soudan                                0.0                          0.0
# Zimbabwe                              6.0                         -0.0
#
#                       Evolution pop (%) Groupe de pays  \
# Zone
# Antigua-et-Barbuda                 1.36      Am?riques
# Bahamas                            1.31      Am?riques
# Grenade                            0.54      Am?riques
# Guinée                             2.68        Afrique
# Maldives                           4.81           Asie
# Mozambique                         3.22        Afrique
# Nouvelle-Calédonie                 1.39        Oc?anie
# Ouganda                            3.96        Afrique
# Polynésie française                0.51        Oc?anie
# Saint-Kitts-et-Nevis               0.89      Am?riques
# Sainte-Lucie                       0.79      Am?riques
# Soudan                              NaN        Afrique
# Zimbabwe                           1.62        Afrique
#
#                       Dispo prot. totale (g/pers/jour)  \
# Zone
# Antigua-et-Barbuda                               81.15
# Bahamas                                          61.37
# Grenade                                          70.57
# Guinée                                           61.78
# Maldives                                         81.63
# Mozambique                                       51.18
# Nouvelle-Calédonie                               83.12
# Ouganda                                          52.32
# Polynésie française                              97.51
# Saint-Kitts-et-Nevis                             76.86
# Sainte-Lucie                                     86.26
# Soudan                                           67.88
# Zimbabwe                                         51.20
#
#                       Dispo prot. animale (g/pers/jour)  PIB par hab.  \
# Zone
# Antigua-et-Barbuda                                  NaN       19840.3
# Bahamas                                             NaN       35911.7
# Grenade                                             NaN       16217.5
# Guinée                                              NaN        2417.8
# Maldives                                            NaN       18057.9
# Mozambique                                          NaN        1283.7
# Nouvelle-Calédonie                                 50.3       31100.0
# Ouganda                                             NaN        2074.7
# Polynésie française                                62.3       17000.0
# Saint-Kitts-et-Nevis                                NaN       26980.3
# Sainte-Lucie                                        NaN       14928.4
# Soudan                                             20.3        4598.9
# Zimbabwe                                            NaN        3795.6
#
#                       Stabilité politique
# Zone
# Antigua-et-Barbuda                   0.89
# Bahamas                              0.96
# Grenade                              0.60
# Guinée                              -1.33
# Maldives                             0.07
# Mozambique                          -0.06
# Nouvelle-Calédonie                    NaN
# Ouganda                             -0.86
# Polynésie française                   NaN
# Saint-Kitts-et-Nevis                 0.83
# Sainte-Lucie                         0.82
# Soudan                              -2.36
# Zimbabwe                            -0.88

# %%
temp_df.isna().sum()
# Out:
# Alimentation de volaille pour touristes            0
# Autres utilisations (non alimentaire) volaille     0
# Dispo prot volaille(g/pers/jour)                   0
# Dispo int. volaille                                0
# Exportation de volaille                            0
# Importation de volaille                            0
# Nourriture de volaille                             0
# Pertes volaille                                    0
# Production de volaille                             0
# Résidus volaille                                   0
# Traitement volaille                                0
# Variation de stock volaille                        0
# Evolution pop (%)                                  1
# Groupe de pays                                     0
# Dispo prot. totale (g/pers/jour)                   0
# Dispo prot. animale (g/pers/jour)                 10
# PIB par hab.                                       0
# Stabilité politique                                2
# dtype: int64

# %% [markdown]
# Je sauvegarde la liste des continents puis je supprime la colonne pour ne garder que les valeurs numériques pour pouvoir faire mon imputation.

# %%
continent_df=temp_df["Groupe de pays"]

# %%
temp_df=temp_df.loc[:,temp_df.columns != 'Groupe de pays']

# %% [markdown]
# J'impute la valeur des n plus proches voisins avec la méthode KNNImputer

# %%
imputer = KNNImputer(n_neighbors=2, weights="distance")
temp_df = pd.DataFrame(imputer.fit_transform(temp_df), columns = temp_df.columns, index=temp_df.index)
temp_df=temp_df.round(2)

# %% [markdown]
# Je remets la colonne *Groupe de pays* dans le dataframe

# %%
temp_df["Continent"]=continent_df

# %% [markdown]
# Vérification de l'imputation

# %%
temp_df[temp_df.index=="Nouvelle-Calédonie"]
# Out:
#                     Alimentation de volaille pour touristes  \
# Zone
# Nouvelle-Calédonie                                      0.0
#
#                     Autres utilisations (non alimentaire) volaille  \
# Zone
# Nouvelle-Calédonie                                             0.0
#
#                     Dispo prot volaille(g/pers/jour)  Dispo int. volaille  \
# Zone
# Nouvelle-Calédonie                             14.05                 11.0
#
#                     Exportation de volaille  Importation de volaille  \
# Zone
# Nouvelle-Calédonie                      0.0                      9.0
#
#                     Nourriture de volaille  Pertes volaille  \
# Zone
# Nouvelle-Calédonie                    11.0              0.0
#
#                     Production de volaille  Résidus volaille  \
# Zone
# Nouvelle-Calédonie                     1.0               0.0
#
#                     Traitement volaille  Variation de stock volaille  \
# Zone
# Nouvelle-Calédonie                  0.0                         -1.0
#
#                     Evolution pop (%)  Dispo prot. totale (g/pers/jour)  \
# Zone
# Nouvelle-Calédonie               1.39                             83.12
#
#                     Dispo prot. animale (g/pers/jour)  PIB par hab.  \
# Zone
# Nouvelle-Calédonie                               50.3       31100.0
#
#                     Stabilité politique Continent
# Zone
# Nouvelle-Calédonie                 0.45   Oc?anie

# %% [markdown]
# ## Création de nouveaux indicateurs
#
# **Rappel :**<br>
# Moyen d'acquisition = Dispo intérieure = Utilisation<br>
# (Prod - Export + Import + Variation stock) = Disponibilité intérieure = (Pertes + Nourriture + Autres Utilisations + Semences + Traitement + Aliments pour animaux)
#
# **Calcul des indicateurs :**
#
# *Indicateur d'import*
# - Import de volaille / disponibilité intérieure de volaille  : indique la part d'import du pays sur sa disponibilité finale.
#
# *Indicateurs de consommation de protéines d'origines animales*
# - Dispo prot animale / dispo prot totale : quelle part représente la protéine animale dans l'alimentation du pays
# - Dispo prot volaille / dispo prot animale : part de la volaille dans l'alimentation animale
#
# *Indicateur de besoin réel
# - Perte de denrées volailles / disponibilité intérieure volaille: > 0, il y a du gaspillage, donc suffisamment de produit.
#
# *Indicateur de saturation du marché sur la volaille
# - Consommation totale (Pertes + Nourriture + Autres Utilisations + Semences + Traitement + Aliments pour animaux) - Disponibilité (Prod - Export + Import) -  : Si le résultat est nul, ou positif, le marché peut supporter un nouvel arrivant peu importe sa valeur ajoutée. Si le résultat est négatif, il faut arriver avec une valeur ajoutée : prix ou produit.

# %%
acquisition=temp_df["Production de volaille"]-temp_df["Exportation de volaille"] + temp_df["Importation de volaille"]+temp_df["Variation de stock volaille"]
utilisation = temp_df["Pertes volaille"]+temp_df["Nourriture de volaille"]+temp_df["Autres utilisations (non alimentaire) volaille"]+temp_df["Traitement volaille"]+temp_df["Alimentation de volaille pour touristes"]+temp_df["Résidus volaille"]

main_df=temp_df.loc[:,["Continent","Evolution pop (%)", "PIB par hab.","Stabilité politique"]].copy()
main_df["Part non importée volailles (%)"]=100-(round((temp_df["Importation de volaille"]/temp_df["Dispo int. volaille"])*100,2)).replace(np.inf, 0)
main_df["Protéines animales (%)"] = round((temp_df["Dispo prot. animale (g/pers/jour)"] / temp_df["Dispo prot. totale (g/pers/jour)"])*100,2).replace(np.inf, 0)
main_df["Dispo prot animale sur besoin prot (%)"]=round((temp_df["Dispo prot. animale (g/pers/jour)"]/prot)*100,2).replace(np.inf,0)
main_df["Prot. de volailles sur prot. animales (%)"] = round((temp_df["Dispo prot volaille(g/pers/jour)"]/temp_df["Dispo prot. animale (g/pers/jour)"])*100,2).replace(np.inf, 0)
main_df["Part non perdue (%)"] = 100-(round((temp_df["Pertes volaille"]/temp_df["Dispo int. volaille"])*100,2)).replace(np.inf,0) # Je calcule ce qui n'est pas perdu pour avoir un chiffre haut quand la valeur est bonne.
main_df["Saturation du marché"]=utilisation-acquisition

#main_df["Pertes (%)"] = round((temp_df["Pertes volaille"]/temp_df["Dispo int. volaille"])*100,2).replace(np.inf,0) # Je calcule ce qui n'est pas perdu pour avoir un chiffre haut quand la valeur est bonne.
#main_df["Saturation du marché"]=acquisition-utilisation
main_df.Continent.replace(["Am?riques","Oc?anie"], ["Amériques","Océanie"], inplace=True)

# %%
main_df
# Out:
#                        Continent  Evolution pop (%)  PIB par hab.  \
# Zone
# Afghanistan                 Asie               3.39        2058.4
# Afrique du Sud           Afrique               1.61       13860.3
# Albanie                   Europe              -0.49       12771.0
# Algérie                  Afrique               2.11       11737.4
# Allemagne                 Europe               0.17       53071.5
# ...                          ...                ...           ...
# Émirats arabes unis         Asie               5.38       67183.6
# Équateur               Amériques               1.74       11617.9
# États-Unis d'Amérique  Amériques               0.81       59914.8
# Éthiopie                 Afrique               3.19        2021.6
# Îles Salomon             Océanie               2.92        2663.5
#
#                        Stabilité politique  Part non importée volailles (%)  \
# Zone
# Afghanistan                          -2.57                            49.12
# Afrique du Sud                       -0.06                            75.73
# Albanie                               0.07                            19.15
# Algérie                              -1.17                            99.28
# Allemagne                             0.82                            51.58
# ...                                    ...                              ...
# Émirats arabes unis                   0.80                            -5.10
# Équateur                             -0.41                           100.00
# États-Unis d'Amérique                 0.52                            99.33
# Éthiopie                             -1.58                            92.86
# Îles Salomon                          0.33                          -100.00
#
#                        Protéines animales (%)  \
# Zone
# Afghanistan                             19.78
# Afrique du Sud                          42.83
# Albanie                                 51.05
# Algérie                                 26.93
# Allemagne                               60.54
# ...                                       ...
# Émirats arabes unis                     32.07
# Équateur                                46.68
# États-Unis d'Amérique                   64.25
# Éthiopie                                 9.14
# Îles Salomon                            28.52
#
#                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                             21.57
# Afrique du Sud                                          71.98
# Albanie                                                122.98
# Algérie                                                 50.40
# Allemagne                                              127.02
# ...                                                       ...
# Émirats arabes unis                                     69.35
# Équateur                                                61.90
# États-Unis d'Amérique                                  147.18
# Éthiopie                                                12.10
# Îles Salomon                                            30.85
#
#                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Afghanistan                                                 5.05
# Afrique du Sud                                             39.52
# Albanie                                                    10.26
# Algérie                                                     7.88
# Allemagne                                                  12.63
# ...                                                          ...
# Émirats arabes unis                                        43.02
# Équateur                                                   20.03
# États-Unis d'Amérique                                      27.30
# Éthiopie                                                    0.67
# Îles Salomon                                                9.87
#
#                        Part non perdue (%)  Saturation du marché
# Zone
# Afghanistan                          96.49                   0.0
# Afrique du Sud                       96.08                   0.0
# Albanie                             100.00                  -8.0
# Algérie                              95.31                   0.0
# Allemagne                           100.00                  57.0
# ...                                    ...                   ...
# Émirats arabes unis                 100.00                  51.0
# Équateur                             95.01                   2.0
# États-Unis d'Amérique               100.00                -159.0
# Éthiopie                             92.86                   0.0
# Îles Salomon                        100.00                  -6.0
#
# [172 rows x 10 columns]

# %% [markdown]
# Je vérifie s'il y a des valeurs nulles je n'ai aucune info.

# %%
print (f"""main_df contient {main_df.shape[0]} pays et {main_df.shape[1]} variables.

Les pays suivant ont des valeurs nulles :
""")
main_df[main_df.isna().any(axis=1)]
# Out:
# main_df contient 172 pays et 10 variables.
#
# Les pays suivant ont des valeurs nulles :
#                                       Continent  Evolution pop (%)  \
# Zone
# Ouzbékistan                                Asie               1.75
# République démocratique populaire lao      Asie               1.70
#
#                                        PIB par hab.  Stabilité politique  \
# Zone
# Ouzbékistan                                  6840.7                -0.64
# République démocratique populaire lao        7257.8                 0.13
#
#                                        Part non importée volailles (%)  \
# Zone
# Ouzbékistan                                                        NaN
# République démocratique populaire lao                              NaN
#
#                                        Protéines animales (%)  \
# Zone
# Ouzbékistan                                             44.91
# République démocratique populaire lao                   22.00
#
#                                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Ouzbékistan                                                             84.68
# République démocratique populaire lao                                   36.90
#
#                                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Ouzbékistan                                                                 1.50
# République démocratique populaire lao                                      19.62
#
#                                        Part non perdue (%)  \
# Zone
# Ouzbékistan                                            NaN
# République démocratique populaire lao                  NaN
#
#                                        Saturation du marché
# Zone
# Ouzbékistan                                             0.0
# République démocratique populaire lao                   0.0

# %%
main_df.dropna(inplace=True)
print (f"Il reste {main_df.shape[0]} pays après suppression des valeurs nulles.")
# Out:
# Il reste 170 pays après suppression des valeurs nulles.

# %% [markdown]
# ## Vérification de la distribution de nos variables (gaussienne ou pas)
#
# **Méthode :**<br>
# Exécution de la fonction normaltest de la librairie scipy.stats
#
# **Hypothèses :<br>**
# - H0 : Variable ayant une distribution gaussienne si p-value > alpha<br>
# - H1 : Variable non distribuée normalement si p-value < alpha<br>
# - Seuil de risque alpha (p-value) = 0.05, soit un risque de 5 % de conclure à tort que la distribution n'est pas normale.
#
# Nous fixons notre seuil de risque à 5%, afin de ne pas rejeter trop facilement les variables candidates.

# %%
alpha = 0.05
test_df = main_df.drop('Continent', axis=1)

for var in test_df.columns:
    k2, p = st.normaltest(test_df[var])
    
    if (p > alpha):
        print(colored((f"{var} : Distribution gaussienne (p-value = {p:.4f})."),'blue'))
    else:
        print(colored((f"{var} : Distribution non gaussienne (p-value = {p:.4f})."),'green'))
# Out:
# Evolution pop (%) : Distribution non gaussienne (p-value = 0.0000).
# PIB par hab. : Distribution non gaussienne (p-value = 0.0000).
# Stabilité politique : Distribution non gaussienne (p-value = 0.0172).
# Part non importée volailles (%) : Distribution non gaussienne (p-value = 0.0000).
# Protéines animales (%) : Distribution non gaussienne (p-value = 0.0056).
# Dispo prot animale sur besoin prot (%) : Distribution non gaussienne (p-value = 0.0161).
# Prot. de volailles sur prot. animales (%) : Distribution non gaussienne (p-value = 0.0001).
# Part non perdue (%) : Distribution non gaussienne (p-value = 0.0000).
# Saturation du marché : Distribution non gaussienne (p-value = 0.0000).

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Recherche d'outliers

# %% [markdown]
# On observe les variables par paire (comme on n'a pas trop de variables) avant de commencer.

# %%
ax=sns.pairplot(main_df.iloc[:,0:10],hue='Continent')

# %% [markdown]
# **Observation**<br>
# On voit clairement au moins 1 gros outlier dans la **saturation du marché**, et 2 dans les **pertes**.
# --------------------

# %% [markdown]
# Je recherche les outliers de chaque variable numérique.

# %%
outliers=[]
var_name=main_df.columns[1:10].copy()

for name in range (len(var_name)):
    median=np.median(main_df[var_name[name]])

    q1=np.median(main_df[main_df[var_name[name]]<=median][var_name[name]])
    q3=np.median(main_df[main_df[var_name[name]]>median][var_name[name]])
    iqr=q3-q1

    outlier_q1=q1-(1.5*iqr)
    outlier_q3=q3+(1.5*iqr)
    
    outliers.append(main_df[(main_df[var_name[name]]>outlier_q3)|(main_df[var_name[name]]<outlier_q1)][var_name[name]].index.values)

    print(colored((f"Les outliers de la variable {var_name[name]} sont les données inférieures à {round(outlier_q1,2)} et supérieures à {round(outlier_q3,2)}"),'blue', attrs=['bold']))   
    if (main_df[(main_df[var_name[name]]>outlier_q3)|(main_df[var_name[name]]<outlier_q1)]).size>1:
        print(f"{main_df[(main_df[var_name[name]]>outlier_q3)|(main_df[var_name[name]]<outlier_q1)][var_name[name]]}")
    else:
        print(f"Il n'y a pas d'outliers pour la variable {var_name[name]}.")
    print("_________________________________________________________________________________________________________________________________________________")
# Out:
# Les outliers de la variable Evolution pop (%) sont les données inférieures à -2.55 et supérieures à 5.53
# Zone
# Jordanie    5.64
# Koweït      6.20
# Oman        7.56
# Name: Evolution pop (%), dtype: float64
# _________________________________________________________________________________________________________________________________________________
# Les outliers de la variable PIB par hab. sont les données inférieures à -31989.15 et supérieures à 66395.25
# Zone
# Chine - RAS de Macao    126144.0
# Irlande                  77749.2
# Luxembourg              114986.0
# Suisse                   69103.6
# Émirats arabes unis      67183.6
# Name: PIB par hab., dtype: float64
# _________________________________________________________________________________________________________________________________________________
# Les outliers de la variable Stabilité politique sont les données inférieures à -2.81 et supérieures à 2.82
# Il n'y a pas d'outliers pour la variable Stabilité politique.
# _________________________________________________________________________________________________________________________________________________
# Les outliers de la variable Part non importée volailles (%) sont les données inférieures à -95.84 et supérieures à 210.8
# Zone
# Belgique                   -122.37
# Chine - RAS de Hong-Kong   -223.93
# Gambie                     -100.00
# Timor-Leste                -120.00
# Îles Salomon               -100.00
# Name: Part non importée volailles (%), dtype: float64
# _________________________________________________________________________________________________________________________________________________
# Les outliers de la variable Protéines animales (%) sont les données inférieures à -11.53 et supérieures à 96.71
# Il n'y a pas d'outliers pour la variable Protéines animales (%).
# _________________________________________________________________________________________________________________________________________________
# Les outliers de la variable Dispo prot animale sur besoin prot (%) sont les données inférieures à -60.89 et supérieures à 205.24
# Zone
# Islande    207.66
# Name: Dispo prot animale sur besoin prot (%), dtype: float64
# _________________________________________________________________________________________________________________________________________________
# Les outliers de la variable Prot. de volailles sur prot. animales (%) sont les données inférieures à -13.35 et supérieures à 49.61
# Zone
# Grenade                            60.95
# Saint-Vincent-et-les Grenadines    50.91
# Name: Prot. de volailles sur prot. animales (%), dtype: float64
# _________________________________________________________________________________________________________________________________________________
# Les outliers de la variable Part non perdue (%) sont les données inférieures à nan et supérieures à nan
# Il n'y a pas d'outliers pour la variable Part non perdue (%).
# _________________________________________________________________________________________________________________________________________________
# Les outliers de la variable Saturation du marché sont les données inférieures à -34.0 et supérieures à 22.0
# Zone
# Allemagne                            57.0
# Arabie saoudite                     215.0
# Australie                          -143.0
# Bolivie (État plurinational de)    -206.0
# Bélarus                            -134.0
# Bénin                                40.0
# Chili                              -160.0
# Chine - RAS de Hong-Kong             24.0
# Chine, Taiwan Province de           -40.0
# Chine, continentale                  99.0
# Croatie                             -45.0
# El Salvador                         -39.0
# Finlande                            -44.0
# France                             -366.0
# Grèce                              -236.0
# Hongrie                            -148.0
# Inde                                238.0
# Indonésie                            42.0
# Iran (République islamique d')      171.0
# Irlande                              24.0
# Italie                             -112.0
# Japon                             -1718.0
# Malaisie                           -255.0
# Malawi                              -65.0
# Maroc                               -35.0
# Nouvelle-Zélande                    -65.0
# Panama                              -51.0
# Pays-Bas                            164.0
# Pologne                            -450.0
# Portugal                           -147.0
# Roumanie                           -176.0
# République de Corée                -230.0
# Slovaquie                           -51.0
# Suède                               -63.0
# Turquie                            -184.0
# Ukraine                             -99.0
# Égypte                               45.0
# Émirats arabes unis                  51.0
# États-Unis d'Amérique              -159.0
# Name: Saturation du marché, dtype: float64
# _________________________________________________________________________________________________________________________________________________
# /Users/laetitia/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laetitia/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# La variable saturation du marché a beaucoup d'outliers. Je vais supprimer ceux qui sont positifs. Nous ne voulons pas aller sur un marché trop saturé.<br>
# Je supprime également les pays avec beaucoup de pertes.

# %%
#mask_del_outliers=main_df[(main_df["Saturation du marché"]>53)|(main_df.Pertes>12)]

# %%
#main_df.drop(mask_del_outliers.index, inplace=True)

# %% [markdown]
# Le Japon ayant une valeur vraiment trop extrême sur la saturation du marché, je supprime cette ligne.

# %%
main_df.drop(index="Japon", inplace=True)

# %% [markdown]
# J'applatis le fichier outliers qui contient pluseiurs listes.

# %%
import itertools
flat_list = itertools.chain(*outliers)

outliers_list=(list(flat_list))# converting iterable to list

# %% [markdown]
# J'affiche les pays restants ayant au moins un outlier dans une colonne.

# %%
main_df.loc[main_df.index.isin(outliers_list)]
# Out:
#                                  Continent  Evolution pop (%)  PIB par hab.  \
# Zone
# Allemagne                           Europe               0.17       53071.5
# Arabie saoudite                       Asie               3.14       47306.2
# Australie                          Océanie               1.75       48398.5
# Belgique                            Europe               0.68       50442.3
# Bolivie (État plurinational de)  Amériques               1.71        8423.7
# ...                                    ...                ...           ...
# Ukraine                             Europe              -0.41       11860.6
# Égypte                             Afrique               2.33       11014.5
# Émirats arabes unis                   Asie               5.38       67183.6
# États-Unis d'Amérique            Amériques               0.81       59914.8
# Îles Salomon                       Océanie               2.92        2663.5
#
#                                  Stabilité politique  \
# Zone
# Allemagne                                       0.82
# Arabie saoudite                                -0.45
# Australie                                       0.95
# Belgique                                        0.73
# Bolivie (État plurinational de)                -0.44
# ...                                              ...
# Ukraine                                        -0.79
# Égypte                                         -1.19
# Émirats arabes unis                             0.80
# États-Unis d'Amérique                           0.52
# Îles Salomon                                    0.33
#
#                                  Part non importée volailles (%)  \
# Zone
# Allemagne                                                  51.58
# Arabie saoudite                                            49.69
# Australie                                                  98.63
# Belgique                                                 -122.37
# Bolivie (État plurinational de)                            99.77
# ...                                                          ...
# Ukraine                                                    88.01
# Égypte                                                     91.20
# Émirats arabes unis                                        -5.10
# États-Unis d'Amérique                                      99.33
# Îles Salomon                                             -100.00
#
#                                  Protéines animales (%)  \
# Zone
# Allemagne                                         60.54
# Arabie saoudite                                   39.54
# Australie                                         66.94
# Belgique                                          56.93
# Bolivie (État plurinational de)                   51.17
# ...                                                 ...
# Ukraine                                           44.11
# Égypte                                            25.66
# Émirats arabes unis                               32.07
# États-Unis d'Amérique                             64.25
# Îles Salomon                                      28.52
#
#                                  Dispo prot animale sur besoin prot (%)  \
# Zone
# Allemagne                                                        127.02
# Arabie saoudite                                                   69.76
# Australie                                                        145.77
# Belgique                                                         116.33
# Bolivie (État plurinational de)                                   70.56
# ...                                                                 ...
# Ukraine                                                           76.61
# Égypte                                                            49.80
# Émirats arabes unis                                               69.35
# États-Unis d'Amérique                                            147.18
# Îles Salomon                                                      30.85
#
#                                  Prot. de volailles sur prot. animales (%)  \
# Zone
# Allemagne                                                            12.63
# Arabie saoudite                                                      45.00
# Australie                                                            22.96
# Belgique                                                              7.92
# Bolivie (État plurinational de)                                      32.66
# ...                                                                    ...
# Ukraine                                                              19.95
# Égypte                                                               18.26
# Émirats arabes unis                                                  43.02
# États-Unis d'Amérique                                                27.30
# Îles Salomon                                                          9.87
#
#                                  Part non perdue (%)  Saturation du marché
# Zone
# Allemagne                                     100.00                  57.0
# Arabie saoudite                               100.00                 215.0
# Australie                                     100.00                -143.0
# Belgique                                      100.00                  13.0
# Bolivie (État plurinational de)                93.71                -206.0
# ...                                              ...                   ...
# Ukraine                                       100.00                 -99.0
# Égypte                                        100.00                  45.0
# Émirats arabes unis                           100.00                  51.0
# États-Unis d'Amérique                         100.00                -159.0
# Îles Salomon                                  100.00                  -6.0
#
# [51 rows x 10 columns]

# %% [markdown]
# **Observation**<br>
# Malgré la présence d'outliers, je ne souhaite pas supprimer les informations qui ne me semblent pas abérrantes ou anormales lorsqu'on les regarde. Cela fait même partie de l'analyse, les individus avec de fortes valeurs sur certaines variables peuvent être intéressants à envisager et donner du poids à la sélection de ce pays.<br>
# Le problème pour le k-means est que les outliers peuvent fausser le découpage en cluster en attirant certaines données vers eux et donc en déplaçant des clusters.
# -------------------------

# %% [markdown]
# Je créé mon dataframe avec uniquement les valeurs numériques.

# %%
main_df_num=main_df.iloc[:,1:10]

# %% [markdown]
# ## CAH
#
# Classification ascendante hiérarchique : la finalité est de trouver le nombre de cluster idéal. On va "couper" l'arbre pour définir le nombre de classe là où les branches semblent les plus longues.

# %% [markdown]
# On met les données à la même échelle pour pouvoir interpréter la heat map avec l'attribut standard_scale, et on ne garde que les données numériques (exit continent)

# %%
# Preparing data for clustering
X = main_df_num
names = main_df_num.index
X
# Out:
#                        Evolution pop (%)  PIB par hab.  Stabilité politique  \
# Zone
# Afghanistan                         3.39        2058.4                -2.57
# Afrique du Sud                      1.61       13860.3                -0.06
# Albanie                            -0.49       12771.0                 0.07
# Algérie                             2.11       11737.4                -1.17
# Allemagne                           0.17       53071.5                 0.82
# ...                                  ...           ...                  ...
# Émirats arabes unis                 5.38       67183.6                 0.80
# Équateur                            1.74       11617.9                -0.41
# États-Unis d'Amérique               0.81       59914.8                 0.52
# Éthiopie                            3.19        2021.6                -1.58
# Îles Salomon                        2.92        2663.5                 0.33
#
#                        Part non importée volailles (%)  \
# Zone
# Afghanistan                                      49.12
# Afrique du Sud                                   75.73
# Albanie                                          19.15
# Algérie                                          99.28
# Allemagne                                        51.58
# ...                                                ...
# Émirats arabes unis                              -5.10
# Équateur                                        100.00
# États-Unis d'Amérique                            99.33
# Éthiopie                                         92.86
# Îles Salomon                                   -100.00
#
#                        Protéines animales (%)  \
# Zone
# Afghanistan                             19.78
# Afrique du Sud                          42.83
# Albanie                                 51.05
# Algérie                                 26.93
# Allemagne                               60.54
# ...                                       ...
# Émirats arabes unis                     32.07
# Équateur                                46.68
# États-Unis d'Amérique                   64.25
# Éthiopie                                 9.14
# Îles Salomon                            28.52
#
#                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                             21.57
# Afrique du Sud                                          71.98
# Albanie                                                122.98
# Algérie                                                 50.40
# Allemagne                                              127.02
# ...                                                       ...
# Émirats arabes unis                                     69.35
# Équateur                                                61.90
# États-Unis d'Amérique                                  147.18
# Éthiopie                                                12.10
# Îles Salomon                                            30.85
#
#                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Afghanistan                                                 5.05
# Afrique du Sud                                             39.52
# Albanie                                                    10.26
# Algérie                                                     7.88
# Allemagne                                                  12.63
# ...                                                          ...
# Émirats arabes unis                                        43.02
# Équateur                                                   20.03
# États-Unis d'Amérique                                      27.30
# Éthiopie                                                    0.67
# Îles Salomon                                                9.87
#
#                        Part non perdue (%)  Saturation du marché
# Zone
# Afghanistan                          96.49                   0.0
# Afrique du Sud                       96.08                   0.0
# Albanie                             100.00                  -8.0
# Algérie                              95.31                   0.0
# Allemagne                           100.00                  57.0
# ...                                    ...                   ...
# Émirats arabes unis                 100.00                  51.0
# Équateur                             95.01                   2.0
# États-Unis d'Amérique               100.00                -159.0
# Éthiopie                             92.86                   0.0
# Îles Salomon                        100.00                  -6.0
#
# [169 rows x 9 columns]

# %%
# Centering and Reduction
scaler = StandardScaler()
XCR = scaler.fit_transform(X)
# Dataframe viz
pd.DataFrame(XCR, columns=X.columns, index=names)
# Out:
#                        Evolution pop (%)  PIB par hab.  Stabilité politique  \
# Zone
# Afghanistan                     1.242418     -0.883583            -2.811795
# Afrique du Sud                  0.033985     -0.310146             0.019221
# Albanie                        -1.391694     -0.363074             0.165847
# Algérie                         0.373432     -0.413295            -1.232742
# Allemagne                      -0.943624      1.595069             1.011768
# ...                                  ...           ...                  ...
# Émirats arabes unis             2.593419      2.280755             0.989210
# Équateur                        0.122241     -0.419101            -0.375542
# États-Unis d'Amérique          -0.509131      1.927575             0.673400
# Éthiopie                        1.106639     -0.885372            -1.695179
# Îles Salomon                    0.923337     -0.854183             0.459100
#
#                        Part non importée volailles (%)  \
# Zone
# Afghanistan                                  -0.097727
# Afrique du Sud                                0.415483
# Albanie                                      -0.675739
# Algérie                                       0.869676
# Allemagne                                    -0.050283
# ...                                                ...
# Émirats arabes unis                          -1.143433
# Équateur                                      0.883563
# États-Unis d'Amérique                         0.870641
# Éthiopie                                      0.745858
# Îles Salomon                                 -2.973708
#
#                        Protéines animales (%)  \
# Zone
# Afghanistan                         -1.425033
# Afrique du Sud                      -0.008053
# Albanie                              0.497264
# Algérie                             -0.985493
# Allemagne                            1.080654
# ...                                       ...
# Émirats arabes unis                 -0.669516
# Équateur                             0.228622
# États-Unis d'Amérique                1.308723
# Éthiopie                            -2.079118
# Îles Salomon                        -0.887749
#
#                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                         -1.290025
# Afrique du Sud                                      -0.063747
# Albanie                                              1.176883
# Algérie                                             -0.588704
# Allemagne                                            1.275160
# ...                                                       ...
# Émirats arabes unis                                 -0.127725
# Équateur                                            -0.308954
# États-Unis d'Amérique                                1.765574
# Éthiopie                                            -1.520393
# Îles Salomon                                        -1.064279
#
#                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Afghanistan                                            -1.170078
# Afrique du Sud                                          1.805665
# Albanie                                                -0.720307
# Algérie                                                -0.925768
# Allemagne                                              -0.515708
# ...                                                          ...
# Émirats arabes unis                                     2.107815
# Équateur                                                0.123123
# États-Unis d'Amérique                                   0.750731
# Éthiopie                                               -1.548197
# Îles Salomon                                           -0.753975
#
#                        Part non perdue (%)  Saturation du marché
# Zone
# Afghanistan                      -0.694692              0.231734
# Afrique du Sud                   -0.837603              0.231734
# Albanie                           0.528764              0.124438
# Algérie                          -1.105996              0.231734
# Allemagne                         0.528764              0.996219
# ...                                    ...                   ...
# Émirats arabes unis               0.528764              0.915747
# Équateur                         -1.210565              0.258558
# États-Unis d'Amérique             0.528764             -1.900776
# Éthiopie                         -1.959975              0.231734
# Îles Salomon                      0.528764              0.151262
#
# [169 rows x 9 columns]

# %% [markdown]
# Je vérifie que les données sont bien proche de 0 pour la moyenne, et égales à 1 pour l'écart-type (action du centrage réduction)

# %%
mean_and_standard_deviation_info(XCR)
# Out:
# Moyennes:
# -1.658400205094251e-16
#
# Ecart-type :
# 1.0

# %% [markdown]
# Choix théorique de la meilleure liaison de clustering pour la CAH, , grâce au concept de coefficient cophénétique.<br>
# Plus le coefficient est proche de 1, mieux le clustering préserve les distances d'origine.

# %%
best_linkage_ach(XCR)
# Out:
# La meilleure méthode théorique de lien est la 'centroid'.

# %% [markdown]
# Le découpage de la classification hiérarchique se fait après la 1re visualisation du dendrogramme.<br>
# En principe, on coupe vers le haut, là où les branches sont les plus longues. <br>
# La méthode de ward, qui ne présente pas le meilleur coefficient cophénéitique ici, sera privilégie car donnant de meilleurs résultats de découpage : il minimise l'inertie intra-classe que ne prennent pas en compte les autres méthodes (uniquement la distance), ce qui permet d'avoir des clusters homogènes.

# %%
Z = linkage(XCR, method="ward",metric="euclidean")
plot_dendrogram(XCR,Z,13)

# %% [markdown]
# ### Analyse

# %%
number_of_clusters=5# Clusters are colored on the dendogram below
CAH_groups = fcluster(Z, number_of_clusters, criterion='maxclust') # ou fcluster(Z, threshold, criterion='distance')

display_countries_from_clusters(number_of_clusters, CAH_groups)
# Out:
# Affichage des 5 clusters
#
# Cluster 1 :
# Allemagne, Autriche, Belgique, Chine - RAS de Hong-Kong, Chine - RAS de Macao, Danemark, Finlande, Irlande, Islande, Luxembourg, Norvège, Pays-Bas, Suisse, Suède
#
# Cluster 2 :
# Australie, Bolivie (État plurinational de), Bélarus, Chili, France, Grèce, Hongrie, Italie, Malaisie, Pologne, Portugal, Roumanie, République de Corée, Turquie, États-Unis d'Amérique
#
# Cluster 3 :
# Afrique du Sud, Albanie, Antigua-et-Barbuda, Arabie saoudite, Argentine, Arménie, Bahamas, Barbade, Belize, Bosnie-Herzégovine, Brésil, Bulgarie, Canada, Chine, Taiwan Province de, Chypre, Costa Rica, Croatie, Cuba, Dominique, El Salvador, Espagne, Estonie, Fidji, Fédération de Russie, Grenade, Guatemala, Guyana, Géorgie, Honduras, Iran (République islamique d'), Israël, Jamaïque, Kazakhstan, Lettonie, Lituanie, Macédoine du Nord, Malte, Maroc, Maurice, Mongolie, Monténégro, Nicaragua, Nouvelle-Calédonie, Nouvelle-Zélande, Panama, Polynésie française, Royaume-Uni de Grande-Bretagne et d'Irlande du Nord, République de Moldova, République dominicaine, Saint-Kitts-et-Nevis, Saint-Vincent-et-les Grenadines, Sainte-Lucie, Samoa, Serbie, Slovaquie, Slovénie, Suriname, Tchéquie, Trinité-et-Tobago, Tunisie, Ukraine, Uruguay
#
# Cluster 4 :
# Angola, Botswana, Bénin, Cabo Verde, Congo, Djibouti, Gabon, Gambie, Ghana, Guinée, Guinée-Bissau, Haïti, Jordanie, Kirghizistan, Kiribati, Koweït, Lesotho, Libéria, Maldives, Mauritanie, Namibie, Oman, Sao Tomé-et-Principe, Tadjikistan, Timor-Leste, Togo, Vanuatu, Émirats arabes unis, Îles Salomon
#
# Cluster 5 :
# Afghanistan, Algérie, Azerbaïdjan, Bangladesh, Burkina Faso, Cambodge, Cameroun, Chine, continentale, Colombie, Côte d'Ivoire, Eswatini, Inde, Indonésie, Iraq, Kenya, Liban, Madagascar, Malawi, Mali, Mexique, Mozambique, Myanmar, Niger, Nigéria, Népal, Ouganda, Pakistan, Paraguay, Philippines, Pérou, Rwanda, République centrafricaine, République populaire démocratique de Corée, République-Unie de Tanzanie, Sierra Leone, Soudan, Sri Lanka, Sénégal, Tchad, Thaïlande, Turkménistan, Venezuela (République bolivarienne du), Viet Nam, Yémen, Zambie, Zimbabwe, Égypte, Équateur, Éthiopie

# %% [markdown]
# Je créé un dataframe avec l'information de continent et de clusters pour voir la répartition géographique

# %%
# Characterization of clusters according to the continent
continent_distrib = pd.DataFrame({"Continent":main_df.Continent,"Cluster": CAH_groups })
print("Affichage du tableau de contingence")
continent_distrib.pivot_table(index="Continent", columns="Cluster", aggfunc=len, fill_value=0, margins=True)
# Out:
# Affichage du tableau de contingence
# Cluster     1   2   3   4   5  All
# Continent
# Afrique     0   0   4  17  24   45
# Amériques   0   3  25   1   6   35
# Asie        2   3   9   8  19   41
# Europe     12   8  19   0   0   39
# Océanie     0   1   5   3   0    9
# All        14  15  62  29  49  169

# %% [markdown]
# Affectation des clusters pour chaque individu adns le dataframe principal

# %%
print("Affichage du cluster pour chaque individu")
#CAH_groups = fcluster(Z, threshold, criterion='distance') # second method to do it. For 1st one, see "clusters" below when you know the number of clusters.
main_df['CAH'] = CAH_groups
main_df
# Out:
# Affichage du cluster pour chaque individu
#                        Continent  Evolution pop (%)  PIB par hab.  \
# Zone
# Afghanistan                 Asie               3.39        2058.4
# Afrique du Sud           Afrique               1.61       13860.3
# Albanie                   Europe              -0.49       12771.0
# Algérie                  Afrique               2.11       11737.4
# Allemagne                 Europe               0.17       53071.5
# ...                          ...                ...           ...
# Émirats arabes unis         Asie               5.38       67183.6
# Équateur               Amériques               1.74       11617.9
# États-Unis d'Amérique  Amériques               0.81       59914.8
# Éthiopie                 Afrique               3.19        2021.6
# Îles Salomon             Océanie               2.92        2663.5
#
#                        Stabilité politique  Part non importée volailles (%)  \
# Zone
# Afghanistan                          -2.57                            49.12
# Afrique du Sud                       -0.06                            75.73
# Albanie                               0.07                            19.15
# Algérie                              -1.17                            99.28
# Allemagne                             0.82                            51.58
# ...                                    ...                              ...
# Émirats arabes unis                   0.80                            -5.10
# Équateur                             -0.41                           100.00
# États-Unis d'Amérique                 0.52                            99.33
# Éthiopie                             -1.58                            92.86
# Îles Salomon                          0.33                          -100.00
#
#                        Protéines animales (%)  \
# Zone
# Afghanistan                             19.78
# Afrique du Sud                          42.83
# Albanie                                 51.05
# Algérie                                 26.93
# Allemagne                               60.54
# ...                                       ...
# Émirats arabes unis                     32.07
# Équateur                                46.68
# États-Unis d'Amérique                   64.25
# Éthiopie                                 9.14
# Îles Salomon                            28.52
#
#                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                             21.57
# Afrique du Sud                                          71.98
# Albanie                                                122.98
# Algérie                                                 50.40
# Allemagne                                              127.02
# ...                                                       ...
# Émirats arabes unis                                     69.35
# Équateur                                                61.90
# États-Unis d'Amérique                                  147.18
# Éthiopie                                                12.10
# Îles Salomon                                            30.85
#
#                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Afghanistan                                                 5.05
# Afrique du Sud                                             39.52
# Albanie                                                    10.26
# Algérie                                                     7.88
# Allemagne                                                  12.63
# ...                                                          ...
# Émirats arabes unis                                        43.02
# Équateur                                                   20.03
# États-Unis d'Amérique                                      27.30
# Éthiopie                                                    0.67
# Îles Salomon                                                9.87
#
#                        Part non perdue (%)  Saturation du marché  CAH
# Zone
# Afghanistan                          96.49                   0.0    5
# Afrique du Sud                       96.08                   0.0    3
# Albanie                             100.00                  -8.0    3
# Algérie                              95.31                   0.0    5
# Allemagne                           100.00                  57.0    1
# ...                                    ...                   ...  ...
# Émirats arabes unis                 100.00                  51.0    4
# Équateur                             95.01                   2.0    5
# États-Unis d'Amérique               100.00                -159.0    2
# Éthiopie                             92.86                   0.0    5
# Îles Salomon                        100.00                  -6.0    4
#
# [169 rows x 11 columns]

# %% [markdown]
# On compare maintenant chaque groupe d'individus par rapports à nos variables

# %%
for item in main_df.columns[1:len(main_df.columns)-1]:
    build_plot(main_df,item, "CAH")

# %% [markdown]
# Visualisation sur une heatmap par groupe

# %%
clustermap_CAH=main_df.iloc[:,1:11]
build_clustermap(clustermap_CAH,"CAH")

# %% [markdown]
# **CAH par variables :<br>**
# - Le taux annuel de la **croissance démographique** de la population mondiale est de 1,2 % ([source](https://fr.wikipedia.org/wiki/Population_mondiale#cite_note-prb2016-1)). Les groupes 4 et 5 ont le plus fort taux d'augmenation annuel de leur population en 10 ans.
#
# - Le **PIB** moyen en dollars PAA (Parité du Pouvoir d'Achat) en 2017 est de ~16 000 dollars. Les groupes 1 et 2 se démarquent sur cet indicateur.
#
# - Le groupe 5 est à envisager avec précaution si on ne veut pas s'aventurer dans des pays dont le commerce des affaires, lié à la **stabilité politique**, n'est pas probant. Le groupe 1 est le plus stable avec aucune valeur négative.
#
# - Le groupe 1 a le plus recours à l'**importation** pour la volaille.  Il serait plus pertinent de se diriger vers des pays important peu et donc avec moins de concurrence : alors les groupes 2 et 5 s'illustrent.
#
# - La **disponibilité de protéines animales** et la **Dispo prot animale sur besoin prot (%)** ont les mêmes tendances : plus élevéeq chez les groupes 1 et 2, et la plus basse dans le groupe 5. Le groupe 5 contient l'Inde et le Mexique qui mangent peu de viande et avec a une populaiton très élevée pour l'Inde, ce qui explique les résultats tirés vers le bas.<br>
#
# - Parmi les protéines animales disponibles, c'est dans les groupes 3 et 4 que la part de **protéines de volailles** est la plus élevée. Ce qui laisse une marge de progression sur les autres groupes.
#
# - Le groupe 2 concentre la plupart des pays dont le **marché est saturé**. On évitera les pays de ce groupe.
#
# - Le groupe 5 a énormément de **pertes** par rapport aux pays des autres groupes, dont les outliers visibles, Pérou et Inde.
#
#
# **Le groupe 1 est le plus équilibré sur l'ensemble des variables**. C'est un groupe riche, qui mange de la protéine animale, qui a une marge de progression sur la part de volaille.<br>
# **On déconseillera le groupe 5 qui est plus végétarien que les autres et qui enregistre beaucoup de perte sur la volaille, et le groupe 2 dont le marché est saturé, bien que les autres indicateurs soient corrects.**<br>
# **Le groupes 3 et 4 sont aussi des choix intéressants** et consomment déjà pas mal de volaille. Le groupe 4 a une bonne marge de progression sur la viande de volaille mais n'est pas très riche mais le groupe 3 reste un meilleur choix en alternative car il est plutôt correct sur l'ensemble des variables.<br>

# %%
main_df[main_df.CAH==5]
# Out:
#               Continent  Evolution pop (%)  PIB par hab.  Stabilité politique  \
# Zone
# Afghanistan        Asie               3.39        2058.4                -2.57
# Algérie         Afrique               2.11       11737.4                -1.17
# Azerbaïdjan        Asie               1.29       14121.4                -0.54
# Bangladesh         Asie               1.19        4894.6                -1.37
# Burkina Faso    Afrique               3.47        2044.4                -0.43
# ...                 ...                ...           ...                  ...
# Zambie          Afrique               3.48        3485.0                 0.38
# Zimbabwe        Afrique               1.62        3795.6                -0.88
# Égypte          Afrique               2.33       11014.5                -1.19
# Équateur      Amériques               1.74       11617.9                -0.41
# Éthiopie        Afrique               3.19        2021.6                -1.58
#
#               Part non importée volailles (%)  Protéines animales (%)  \
# Zone
# Afghanistan                             49.12                   19.78
# Algérie                                 99.28                   26.93
# Azerbaïdjan                             79.07                   34.67
# Bangladesh                             100.00                   19.93
# Burkina Faso                           100.00                   14.06
# ...                                       ...                     ...
# Zambie                                  80.00                   23.20
# Zimbabwe                                92.11                   29.20
# Égypte                                  91.20                   25.66
# Équateur                               100.00                   46.68
# Éthiopie                                92.86                    9.14
#
#               Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                    21.57
# Algérie                                        50.40
# Azerbaïdjan                                    64.52
# Bangladesh                                     24.19
# Burkina Faso                                   21.57
# ...                                              ...
# Zambie                                         27.62
# Zimbabwe                                       30.14
# Égypte                                         49.80
# Équateur                                       61.90
# Éthiopie                                       12.10
#
#               Prot. de volailles sur prot. animales (%)  Part non perdue (%)  \
# Zone
# Afghanistan                                        5.05                96.49
# Algérie                                            7.88                95.31
# Azerbaïdjan                                       13.91               100.00
# Bangladesh                                         3.92                96.00
# Burkina Faso                                       7.20                95.65
# ...                                                 ...                  ...
# Zambie                                             8.39                96.67
# Zimbabwe                                          10.64                96.05
# Égypte                                            18.26               100.00
# Équateur                                          20.03                95.01
# Éthiopie                                           0.67                92.86
#
#               Saturation du marché  CAH
# Zone
# Afghanistan                    0.0    5
# Algérie                        0.0    5
# Azerbaïdjan                   -4.0    5
# Bangladesh                     1.0    5
# Burkina Faso                   0.0    5
# ...                            ...  ...
# Zambie                         0.0    5
# Zimbabwe                       1.0    5
# Égypte                        45.0    5
# Équateur                       2.0    5
# Éthiopie                       0.0    5
#
# [49 rows x 11 columns]

# %% [markdown]
# ## K-means : Paritionnement direct
#
# La CAH n'est pas optimale car on prend en compte une hiérarchie entre les individus. On va tester une autre méthode de clustering pour comparer les résultat.

# %% [markdown]
# ### Méthode du coude

# %% [markdown]
# Pour déterminer le nombre optimal de clusters par la méthode du coude, il faut sélectionner la valeur de k au «coude» du graphique généré, c’est-à-dire le point après lequel la distorsion / inertie commence à diminuer de façon + linéaire.<br>
#
# <u>Distorsion</u> : Elle est calculée comme la moyenne des distances au carré des centres de cluster des clusters respectifs. En règle générale, la métrique de distance euclidienne est utilisée.<br>
# <u>Inertie</u> : C’est la somme des distances au carré des échantillons par rapport à leur centre de cluster le plus proche.
#
# J'itère les valeurs de k de 1 à 10 et calcule les valeurs de la distorsion et l’inertie pour chaque valeur de k dans la plage donnée.

# %%
X
# Out:
#                        Evolution pop (%)  PIB par hab.  Stabilité politique  \
# Zone
# Afghanistan                         3.39        2058.4                -2.57
# Afrique du Sud                      1.61       13860.3                -0.06
# Albanie                            -0.49       12771.0                 0.07
# Algérie                             2.11       11737.4                -1.17
# Allemagne                           0.17       53071.5                 0.82
# ...                                  ...           ...                  ...
# Émirats arabes unis                 5.38       67183.6                 0.80
# Équateur                            1.74       11617.9                -0.41
# États-Unis d'Amérique               0.81       59914.8                 0.52
# Éthiopie                            3.19        2021.6                -1.58
# Îles Salomon                        2.92        2663.5                 0.33
#
#                        Part non importée volailles (%)  \
# Zone
# Afghanistan                                      49.12
# Afrique du Sud                                   75.73
# Albanie                                          19.15
# Algérie                                          99.28
# Allemagne                                        51.58
# ...                                                ...
# Émirats arabes unis                              -5.10
# Équateur                                        100.00
# États-Unis d'Amérique                            99.33
# Éthiopie                                         92.86
# Îles Salomon                                   -100.00
#
#                        Protéines animales (%)  \
# Zone
# Afghanistan                             19.78
# Afrique du Sud                          42.83
# Albanie                                 51.05
# Algérie                                 26.93
# Allemagne                               60.54
# ...                                       ...
# Émirats arabes unis                     32.07
# Équateur                                46.68
# États-Unis d'Amérique                   64.25
# Éthiopie                                 9.14
# Îles Salomon                            28.52
#
#                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                             21.57
# Afrique du Sud                                          71.98
# Albanie                                                122.98
# Algérie                                                 50.40
# Allemagne                                              127.02
# ...                                                       ...
# Émirats arabes unis                                     69.35
# Équateur                                                61.90
# États-Unis d'Amérique                                  147.18
# Éthiopie                                                12.10
# Îles Salomon                                            30.85
#
#                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Afghanistan                                                 5.05
# Afrique du Sud                                             39.52
# Albanie                                                    10.26
# Algérie                                                     7.88
# Allemagne                                                  12.63
# ...                                                          ...
# Émirats arabes unis                                        43.02
# Équateur                                                   20.03
# États-Unis d'Amérique                                      27.30
# Éthiopie                                                    0.67
# Îles Salomon                                                9.87
#
#                        Part non perdue (%)  Saturation du marché
# Zone
# Afghanistan                          96.49                   0.0
# Afrique du Sud                       96.08                   0.0
# Albanie                             100.00                  -8.0
# Algérie                              95.31                   0.0
# Allemagne                           100.00                  57.0
# ...                                    ...                   ...
# Émirats arabes unis                 100.00                  51.0
# Équateur                             95.01                   2.0
# États-Unis d'Amérique               100.00                -159.0
# Éthiopie                             92.86                   0.0
# Îles Salomon                        100.00                  -6.0
#
# [169 rows x 9 columns]

# %%
# Je repars de mon df X qui ne contient que les variables numériques et pas la colonne CAH

mean_and_standard_deviation_info(X)
# Out:
# Moyennes:
# Evolution pop (%)                                1.559941
# PIB par hab.                                 20243.414201
# Stabilité politique                             -0.077041
# Part non importée volailles (%)                 54.187160
# Protéines animales (%)                          42.961006
# Dispo prot animale sur besoin prot (%)          74.600533
# Prot. de volailles sur prot. animales (%)       18.603787
# Part non perdue (%)                             98.483018
# Saturation du marché                           -17.278107
# dtype: float64
#
# Ecart-type :
# Evolution pop (%)                                1.477359
# PIB par hab.                                 20642.143141
# Stabilité politique                              0.889242
# Part non importée volailles (%)                 52.004228
# Protéines animales (%)                          16.315337
# Dispo prot animale sur besoin prot (%)          41.230310
# Prot. de volailles sur prot. animales (%)       11.618085
# Part non perdue (%)                              2.877448
# Saturation du marché                            74.781584
# dtype: float64

# %% [markdown]
# Je centre et réduis manuellement (pour essayer une autre technique) : je retranche la moyenne au dataframe et je divise par l'écart-type.<br>
# J'affiche ensuite le résultat. Si la moyenne vaut 0 (ou presque) et l'écart-type 1, c'est ok.

# %%
XCR_km=(X - X.mean())/X.std()
#X_CR_km=(X.sub(X.mean())).div(X.std()) -> autre méthode
mean_and_standard_deviation_info(XCR_km)
# Out:
# Moyennes:
# Evolution pop (%)                            4.519725e-16
# PIB par hab.                                 4.204395e-17
# Stabilité politique                          9.854051e-18
# Part non importée volailles (%)             -5.439436e-16
# Protéines animales (%)                       1.845992e-16
# Dispo prot animale sur besoin prot (%)      -6.464257e-16
# Prot. de volailles sur prot. animales (%)   -4.125562e-16
# Part non perdue (%)                          3.134902e-15
# Saturation du marché                        -2.726287e-17
# dtype: float64
#
# Ecart-type :
# Evolution pop (%)                            1.0
# PIB par hab.                                 1.0
# Stabilité politique                          1.0
# Part non importée volailles (%)              1.0
# Protéines animales (%)                       1.0
# Dispo prot animale sur besoin prot (%)       1.0
# Prot. de volailles sur prot. animales (%)    1.0
# Part non perdue (%)                          1.0
# Saturation du marché                         1.0
# dtype: float64

# %%
#distortions = [] 
inertias = [] 

K = range(1,10) 
  
for k in K: 
    kmeanModel = KMeans(n_clusters=k,n_init=10, init='k-means++',random_state=0)
    kmeanModel = kmeanModel.fit(XCR_km)
    #distortions.append(sum(np.min(cdist(X_CR_km, kmeanModel.cluster_centers_,'euclidean'),axis=1)) / X_CR_km.shape[0]) 
    inertias.append(kmeanModel.inertia_)  

plt.plot(K, inertias, 'bx-') #plt.plot(K, distortions, 'bx-') 
plt.xlabel('K') 
plt.ylabel('Inertia') #plt.ylabel('Distortion') 
plt.xticks(np.arange(1,10, step=1))
plt.title('The Elbow Method using Inertia') #plt.title('The Elbow Method using Distortion') 
plt.show() 

print (f"""Valeurs d'inertie :
{inertias}
""")
# Out:
# Valeurs d'inertie :
# [1512.0000000000005, 1061.0052913701788, 917.4164499681533, 818.7428764451831, 724.0387060924211, 676.8969409460392, 617.0289395482348, 561.0092953993511, 516.715771483158]

# %% [markdown]
# **Observation**<br>
# Le graphique nous montre a priori un "coude" sur la valeur 2. <br>
# On peut voir un léger coude sur la valeur 5 également.
# _________________

# %% [markdown]
# On regarde pour 5 clusters car 2 n'est pas un nombre suffisant.

# %%
result_5k = KMeans(n_clusters=5, n_init=10, init='k-means++',random_state=0)
result_5k.fit(XCR_km)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %% [markdown]
# On affiche les centres de classes.

# %%
pd.DataFrame(result_5k.cluster_centers_)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.637774 -0.759743 -1.027278  0.656929 -1.124290 -1.016957 -0.892272
# 1 -0.689478  0.600394  0.406010  0.587891  0.731888  0.862815  0.116676
# 2  1.257834 -0.380942 -0.157150 -1.017864 -0.621650 -0.694431  0.258907
# 3 -0.604924  1.113960  0.994151 -0.496607  1.174845  1.207109 -0.180433
# 4 -0.495466 -0.301785 -0.070341  0.311014  0.021078 -0.084798  0.637385
#
#           7         8
# 0 -1.108825  0.331882
# 1  0.053166 -2.537905
# 2  0.508455  0.335160
# 3  0.389141  0.157166
# 4  0.212789  0.206486

# %% [markdown]
# ### Méthode de visualisation du coude - kelbow_visualizer
# On va tester avec un visualiseur "automatique" de coude pour voir ce qui est préconisé comme découpage.

# %%
elbow = kelbow_visualizer(result_5k, X=XCR_km, k=(1,10), metric='distortion', timings=False)

#ou 

#from yellowbrick.cluster import KElbowVisualizer

#elbow = KElbowVisualizer(result,k=(1,10), metric='distortion', timings=False)
#elbow.fit(X_CR_km) # Fit the data to the visualizer
#elbow.show()

# %% [markdown]
# **Observation**<br>
# 3 n'est pas un nombre de clusters suffisant, on reste sur 5 clusters.
# __________________

# %% [markdown]
# ### Méthode de l'analyse du coefficient de silhouette
#
# Je regarde si l'analyse des silhouettes donne le même résultat.

# %% [markdown]
# Calcul des scores de silhouette pour le modèle de clustering K-means avec différentes valeurs pour le nombre de clusters.

# %%
#Use silhouette score
silhouettes=[]
for n_clusters in range(2,10):
    result = KMeans(n_clusters=n_clusters,n_init=10, init='k-means++',random_state=0) # Instantiate the Kmeans model with 10 times a random init
    result.fit(XCR_km) # Fit the KMeans model on normalized data
    #centers = result.cluster_centers_
    score = silhouette_score(XCR_km, result.labels_, metric='euclidean') #Calculate Silhoutte coefficient Score 
    silhouettes.append(score)
    
    print(f"Quand le nombre de clusters vaut {n_clusters}, le score de silhouette score vaut {score:.3f}.")  

plt.plot(range(2,10),silhouettes, marker='o') 
plt.show()
# Out:
# Quand le nombre de clusters vaut 2, le score de silhouette score vaut 0.272.
# Quand le nombre de clusters vaut 3, le score de silhouette score vaut 0.205.
# Quand le nombre de clusters vaut 4, le score de silhouette score vaut 0.202.
# Quand le nombre de clusters vaut 5, le score de silhouette score vaut 0.222.
# Quand le nombre de clusters vaut 6, le score de silhouette score vaut 0.199.
# Quand le nombre de clusters vaut 7, le score de silhouette score vaut 0.213.
# Quand le nombre de clusters vaut 8, le score de silhouette score vaut 0.210.
# Quand le nombre de clusters vaut 9, le score de silhouette score vaut 0.213.

# %% [markdown]
# **Il faut privilégier 2 ou 5 clusters pour lesquels le score est le + élevé.**

# %% [markdown]
# Seconde méthode automatisée pour l'indentification du coude avec la librairie dédiée.

# %%
visualizer = kelbow_visualizer(result,X=XCR_km, k=(2,10),metric='silhouette', timings= False)

# %% [markdown]
# La technique 2 montre un clustering de 2.

# %% [markdown]
# ### Méthode de l'analyse des silhouettes

# %% [markdown]
# Analyse des silhouettes avec k de 2 à 8

# %%
fig, ax = plt.subplots(4, 2, figsize=(15,15))

for i in range (2,10):
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=0)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(XCR_km)

# %% [markdown]
# **Observation**<br>
#
# Les groupes 7 et 8 ont un score de silhouette inférieur à la moyenne.<br>
#
# Pour une valeur de 5 à 9 clusters, l'épaisseur de chaque cluster varie trop. Tout comme la taille (longueur) pour les clusters 3 à 9.<br>
#
# Une valeur de 2 pour le nombre de clusters semble optimale. Le score de chaque silhouette est au dessus de la moyenne des scores et la fluctuation à peu près similaires, tout comme l'épaisseur de chaque cluster.
# ________________________

# %% [markdown]
# **Conclusion**<br>
# **Les différentes méthodes de choix de clusters s'accordent pour le nombre de clusters idéal : 2 ou 3.**<br>
# **Le k-means étant sensible aux outliers, les résultats peuvent être biaisés.**
#
# D'ailleurs, en faisant la comparaison entre 5 clusters CAH et 3 clusters k-means, le résultat va dans ce sens.<br>
# Le groupe 2 a été désigné pour la méthode des kmeans, et le groupe 1 pour les CAH.<br>
# Nous n'avons aucun pays en commun entre les groupe car les outliers de la saturation du marché ont dû absorber les autres pays d'Europe.<br>
# Les recommandations théoriques k-means n'autorisent pas une recommandation de petits groupes. Les kmeans sont également plus sensibles aux outliers et nous en avons quelques-uns.<br>
#
# **Nous allons donc faire le clustering k-means sur 5 clusters.**

# %% [markdown]
# ### Analyse

# %% [markdown]
# Ajout du résultat du clustering kmeans avec 5 clusters dans le tableau principal.

# %%
result_5k = KMeans(n_clusters=5, n_init=10, init='k-means++',random_state=0)
result_5k.fit(XCR_km)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
main_df['Kmeans']=result_5k.labels_+1
main_df
# Out:
#                        Continent  Evolution pop (%)  PIB par hab.  \
# Zone
# Afghanistan                 Asie               3.39        2058.4
# Afrique du Sud           Afrique               1.61       13860.3
# Albanie                   Europe              -0.49       12771.0
# Algérie                  Afrique               2.11       11737.4
# Allemagne                 Europe               0.17       53071.5
# ...                          ...                ...           ...
# Émirats arabes unis         Asie               5.38       67183.6
# Équateur               Amériques               1.74       11617.9
# États-Unis d'Amérique  Amériques               0.81       59914.8
# Éthiopie                 Afrique               3.19        2021.6
# Îles Salomon             Océanie               2.92        2663.5
#
#                        Stabilité politique  Part non importée volailles (%)  \
# Zone
# Afghanistan                          -2.57                            49.12
# Afrique du Sud                       -0.06                            75.73
# Albanie                               0.07                            19.15
# Algérie                              -1.17                            99.28
# Allemagne                             0.82                            51.58
# ...                                    ...                              ...
# Émirats arabes unis                   0.80                            -5.10
# Équateur                             -0.41                           100.00
# États-Unis d'Amérique                 0.52                            99.33
# Éthiopie                             -1.58                            92.86
# Îles Salomon                          0.33                          -100.00
#
#                        Protéines animales (%)  \
# Zone
# Afghanistan                             19.78
# Afrique du Sud                          42.83
# Albanie                                 51.05
# Algérie                                 26.93
# Allemagne                               60.54
# ...                                       ...
# Émirats arabes unis                     32.07
# Équateur                                46.68
# États-Unis d'Amérique                   64.25
# Éthiopie                                 9.14
# Îles Salomon                            28.52
#
#                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                             21.57
# Afrique du Sud                                          71.98
# Albanie                                                122.98
# Algérie                                                 50.40
# Allemagne                                              127.02
# ...                                                       ...
# Émirats arabes unis                                     69.35
# Équateur                                                61.90
# États-Unis d'Amérique                                  147.18
# Éthiopie                                                12.10
# Îles Salomon                                            30.85
#
#                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Afghanistan                                                 5.05
# Afrique du Sud                                             39.52
# Albanie                                                    10.26
# Algérie                                                     7.88
# Allemagne                                                  12.63
# ...                                                          ...
# Émirats arabes unis                                        43.02
# Équateur                                                   20.03
# États-Unis d'Amérique                                      27.30
# Éthiopie                                                    0.67
# Îles Salomon                                                9.87
#
#                        Part non perdue (%)  Saturation du marché  CAH  Kmeans
# Zone
# Afghanistan                          96.49                   0.0    5       1
# Afrique du Sud                       96.08                   0.0    3       5
# Albanie                             100.00                  -8.0    3       4
# Algérie                              95.31                   0.0    5       1
# Allemagne                           100.00                  57.0    1       4
# ...                                    ...                   ...  ...     ...
# Émirats arabes unis                 100.00                  51.0    4       3
# Équateur                             95.01                   2.0    5       5
# États-Unis d'Amérique               100.00                -159.0    2       2
# Éthiopie                             92.86                   0.0    5       1
# Îles Salomon                        100.00                  -6.0    4       3
#
# [169 rows x 12 columns]

# %%
num_clusters=len(main_df.Kmeans.unique())
print(f"Affichage des {num_clusters} clusters")
print("")
for i in range(1,num_clusters+1):
    print(f"Cluster {i} :")
    print(f", ".join(main_df.index[main_df.Kmeans == i].sort_values()))
    print(" ")
# Out:
# Affichage des 5 clusters
#
# Cluster 1 :
# Afghanistan, Algérie, Bangladesh, Burkina Faso, Cambodge, Cameroun, Côte d'Ivoire, Guinée, Inde, Indonésie, Kenya, Madagascar, Malawi, Mali, Mozambique, Niger, Nigéria, Népal, Ouganda, Pakistan, Philippines, Pérou, Rwanda, République centrafricaine, République populaire démocratique de Corée, République-Unie de Tanzanie, Sierra Leone, Soudan, Sri Lanka, Sénégal, Tchad, Turkménistan, Yémen, Zambie, Zimbabwe, Égypte, Éthiopie
#
# Cluster 2 :
# Australie, Bolivie (État plurinational de), Bélarus, Chili, France, Grèce, Hongrie, Italie, Malaisie, Pologne, Portugal, Roumanie, République de Corée, Turquie, États-Unis d'Amérique
#
# Cluster 3 :
# Angola, Arabie saoudite, Bénin, Cabo Verde, Congo, Djibouti, Gabon, Gambie, Ghana, Guinée-Bissau, Haïti, Iraq, Jordanie, Kirghizistan, Koweït, Liban, Libéria, Maldives, Mauritanie, Namibie, Oman, Sao Tomé-et-Principe, Tadjikistan, Timor-Leste, Togo, Vanuatu, Émirats arabes unis, Îles Salomon
#
# Cluster 4 :
# Albanie, Allemagne, Antigua-et-Barbuda, Argentine, Autriche, Bahamas, Belgique, Canada, Chine - RAS de Hong-Kong, Chine - RAS de Macao, Chine, Taiwan Province de, Chypre, Croatie, Danemark, Dominique, Espagne, Estonie, Finlande, Irlande, Islande, Kazakhstan, Lettonie, Lituanie, Luxembourg, Malte, Mongolie, Monténégro, Norvège, Nouvelle-Calédonie, Nouvelle-Zélande, Pays-Bas, Polynésie française, Royaume-Uni de Grande-Bretagne et d'Irlande du Nord, Saint-Kitts-et-Nevis, Slovaquie, Slovénie, Suisse, Suède, Tchéquie, Uruguay
#
# Cluster 5 :
# Afrique du Sud, Arménie, Azerbaïdjan, Barbade, Belize, Bosnie-Herzégovine, Botswana, Brésil, Bulgarie, Chine, continentale, Colombie, Costa Rica, Cuba, El Salvador, Eswatini, Fidji, Fédération de Russie, Grenade, Guatemala, Guyana, Géorgie, Honduras, Iran (République islamique d'), Israël, Jamaïque, Kiribati, Lesotho, Macédoine du Nord, Maroc, Maurice, Mexique, Myanmar, Nicaragua, Panama, Paraguay, République de Moldova, République dominicaine, Saint-Vincent-et-les Grenadines, Sainte-Lucie, Samoa, Serbie, Suriname, Thaïlande, Trinité-et-Tobago, Tunisie, Ukraine, Venezuela (République bolivarienne du), Viet Nam, Équateur

# %%
# Characterization of clusters according to the continent
continent_distrib_kmeans = pd.DataFrame({"Continent":main_df.Continent,"Cluster": main_df.Kmeans})
print("Affichage du tableau de contingence")
continent_distrib_kmeans.pivot_table(index="Continent", columns="Cluster", aggfunc=len, fill_value=0, margins=True)
# Out:
# Affichage du tableau de contingence
# Cluster     1   2   3   4   5  All
# Continent
# Afrique    24   0  14   0   7   45
# Amériques   1   3   1   7  23   35
# Asie       12   3  11   6   9   41
# Europe      0   8   0  24   7   39
# Océanie     0   1   2   3   3    9
# All        37  15  28  40  49  169

# %%
main_df
# Out:
#                        Continent  Evolution pop (%)  PIB par hab.  \
# Zone
# Afghanistan                 Asie               3.39        2058.4
# Afrique du Sud           Afrique               1.61       13860.3
# Albanie                   Europe              -0.49       12771.0
# Algérie                  Afrique               2.11       11737.4
# Allemagne                 Europe               0.17       53071.5
# ...                          ...                ...           ...
# Émirats arabes unis         Asie               5.38       67183.6
# Équateur               Amériques               1.74       11617.9
# États-Unis d'Amérique  Amériques               0.81       59914.8
# Éthiopie                 Afrique               3.19        2021.6
# Îles Salomon             Océanie               2.92        2663.5
#
#                        Stabilité politique  Part non importée volailles (%)  \
# Zone
# Afghanistan                          -2.57                            49.12
# Afrique du Sud                       -0.06                            75.73
# Albanie                               0.07                            19.15
# Algérie                              -1.17                            99.28
# Allemagne                             0.82                            51.58
# ...                                    ...                              ...
# Émirats arabes unis                   0.80                            -5.10
# Équateur                             -0.41                           100.00
# États-Unis d'Amérique                 0.52                            99.33
# Éthiopie                             -1.58                            92.86
# Îles Salomon                          0.33                          -100.00
#
#                        Protéines animales (%)  \
# Zone
# Afghanistan                             19.78
# Afrique du Sud                          42.83
# Albanie                                 51.05
# Algérie                                 26.93
# Allemagne                               60.54
# ...                                       ...
# Émirats arabes unis                     32.07
# Équateur                                46.68
# États-Unis d'Amérique                   64.25
# Éthiopie                                 9.14
# Îles Salomon                            28.52
#
#                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                             21.57
# Afrique du Sud                                          71.98
# Albanie                                                122.98
# Algérie                                                 50.40
# Allemagne                                              127.02
# ...                                                       ...
# Émirats arabes unis                                     69.35
# Équateur                                                61.90
# États-Unis d'Amérique                                  147.18
# Éthiopie                                                12.10
# Îles Salomon                                            30.85
#
#                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Afghanistan                                                 5.05
# Afrique du Sud                                             39.52
# Albanie                                                    10.26
# Algérie                                                     7.88
# Allemagne                                                  12.63
# ...                                                          ...
# Émirats arabes unis                                        43.02
# Équateur                                                   20.03
# États-Unis d'Amérique                                      27.30
# Éthiopie                                                    0.67
# Îles Salomon                                                9.87
#
#                        Part non perdue (%)  Saturation du marché  CAH  Kmeans
# Zone
# Afghanistan                          96.49                   0.0    5       1
# Afrique du Sud                       96.08                   0.0    3       5
# Albanie                             100.00                  -8.0    3       4
# Algérie                              95.31                   0.0    5       1
# Allemagne                           100.00                  57.0    1       4
# ...                                    ...                   ...  ...     ...
# Émirats arabes unis                 100.00                  51.0    4       3
# Équateur                             95.01                   2.0    5       5
# États-Unis d'Amérique               100.00                -159.0    2       2
# Éthiopie                             92.86                   0.0    5       1
# Îles Salomon                        100.00                  -6.0    4       3
#
# [169 rows x 12 columns]

# %%
for item in main_df.columns[1:len(main_df.columns)-2]:
    build_plot(main_df,item, "Kmeans")

# %%
clustermap_kmeans=main_df[main_df.columns.difference(['Continent','CAH'])]
build_clustermap(clustermap_kmeans,'Kmeans')

# %% [markdown]
# **Observation<br>**
#
#
# **Le groupe 2**, très visible sur la saturation de marché **devrait être écarté**.<br>
# **Le groupe 1** étant le moins carnivore, le moins riche et le moins stable, mais gaspillant le plus, **sera également écarté.**<br>
# **On sélectionnerait donc les pays du groupe 4.**

# %% [markdown]
# ## Comparaison des résultats entre Kmeans et CAH
#
# Comparaison clustering avec :
# - 5 clusters kmeans
# - 5 clusters CAH

# %%
clusters_df=main_df.iloc[:,10:12].copy() #9:11

# %%
print("Nombre de pays par cluster selon les méthodes de partitionnement")
clusters_df.pivot_table(index="CAH", columns=["Kmeans"], aggfunc=len, fill_value=0, margins=True)
# Out:
# Nombre de pays par cluster selon les méthodes de partitionnement
# Kmeans   1   2   3   4   5  All
# CAH
# 1        0   0   0  14   0   14
# 2        0  15   0   0   0   15
# 3        0   0   1  26  35   62
# 4        1   0  25   0   3   29
# 5       36   0   2   0  11   49
# All     37  15  28  40  49  169

# %% [markdown]
# **Observation**<br>
# Tous les pays du groupe 1 du clustering CAH se retrouve dans le cluster 4 du partitionnement k-means. <br>
# On note aussi que le second choix, à savoir les pays du groupe 3 de la CAH  se retrouvent dans ce groupe k-means 4.<br>
# Les résultats sont cohérents dans ce k-means, même si le groupe cible est plus large (à cause des outlliers?).

# %% [markdown]
# **Choix = Pays du groupe 1 de la CAH**

# %%
final_choice_clustering=main_df[main_df.CAH==1]
final_choice_clustering
# Out:
#                          Continent  Evolution pop (%)  PIB par hab.  \
# Zone
# Allemagne                   Europe               0.17       53071.5
# Autriche                    Europe               0.61       54173.0
# Belgique                    Europe               0.68       50442.3
# Chine - RAS de Hong-Kong      Asie               0.68       59842.2
# Chine - RAS de Macao          Asie               2.34      126144.0
# Danemark                    Europe               0.48       55356.7
# Finlande                    Europe               0.40       47570.1
# Irlande                     Europe               0.99       77749.2
# Islande                     Europe               0.96       55638.5
# Luxembourg                  Europe               2.46      114986.0
# Norvège                     Europe               1.22       64050.8
# Pays-Bas                    Europe               0.31       55088.6
# Suisse                      Europe               1.22       69103.6
# Suède                       Europe               0.81       51948.0
#
#                           Stabilité politique  \
# Zone
# Allemagne                                0.82
# Autriche                                 1.20
# Belgique                                 0.73
# Chine - RAS de Hong-Kong                 0.98
# Chine - RAS de Macao                     0.85
# Danemark                                 0.98
# Finlande                                 1.31
# Irlande                                  1.01
# Islande                                  1.27
# Luxembourg                               1.41
# Norvège                                  1.25
# Pays-Bas                                 0.98
# Suisse                                   1.31
# Suède                                    1.10
#
#                           Part non importée volailles (%)  \
# Zone
# Allemagne                                           51.58
# Autriche                                            36.42
# Belgique                                          -122.37
# Chine - RAS de Hong-Kong                          -223.93
# Chine - RAS de Macao                               -21.05
# Danemark                                            20.36
# Finlande                                            85.59
# Irlande                                             22.66
# Islande                                             80.00
# Luxembourg                                           0.00
# Norvège                                             98.04
# Pays-Bas                                           -63.44
# Suisse                                              61.65
# Suède                                               55.08
#
#                           Protéines animales (%)  \
# Zone
# Allemagne                                  60.54
# Autriche                                   59.85
# Belgique                                   56.93
# Chine - RAS de Hong-Kong                   69.41
# Chine - RAS de Macao                       67.75
# Danemark                                   68.19
# Finlande                                   63.09
# Irlande                                    64.27
# Islande                                    72.87
# Luxembourg                                 63.90
# Norvège                                    60.65
# Pays-Bas                                   65.12
# Suisse                                     63.59
# Suède                                      63.25
#
#                           Dispo prot animale sur besoin prot (%)  \
# Zone
# Allemagne                                                 127.02
# Autriche                                                  130.44
# Belgique                                                  116.33
# Chine - RAS de Hong-Kong                                  192.94
# Chine - RAS de Macao                                      137.10
# Danemark                                                  155.24
# Finlande                                                  149.80
# Irlande                                                   137.10
# Islande                                                   207.66
# Luxembourg                                                136.29
# Norvège                                                   134.48
# Pays-Bas                                                  137.10
# Suisse                                                    122.38
# Suède                                                     136.49
#
#                           Prot. de volailles sur prot. animales (%)  \
# Zone
# Allemagne                                                     12.63
# Autriche                                                      11.58
# Belgique                                                       7.92
# Chine - RAS de Hong-Kong                                      23.26
# Chine - RAS de Macao                                          17.50
# Danemark                                                      16.84
# Finlande                                                      10.59
# Irlande                                                       17.06
# Islande                                                       11.97
# Luxembourg                                                    10.64
# Norvège                                                       11.71
# Pays-Bas                                                      12.47
# Suisse                                                        10.69
# Suède                                                         10.47
#
#                           Part non perdue (%)  Saturation du marché  CAH  \
# Zone
# Allemagne                               100.0                  57.0    1
# Autriche                                100.0                 -16.0    1
# Belgique                                100.0                  13.0    1
# Chine - RAS de Hong-Kong                100.0                  24.0    1
# Chine - RAS de Macao                    100.0                 -16.0    1
# Danemark                                100.0                   0.0    1
# Finlande                                100.0                 -44.0    1
# Irlande                                 100.0                  24.0    1
# Islande                                 100.0                  -3.0    1
# Luxembourg                              100.0                   1.0    1
# Norvège                                 100.0                  -2.0    1
# Pays-Bas                                100.0                 164.0    1
# Suisse                                  100.0                 -10.0    1
# Suède                                   100.0                 -63.0    1
#
#                           Kmeans
# Zone
# Allemagne                      4
# Autriche                       4
# Belgique                       4
# Chine - RAS de Hong-Kong       4
# Chine - RAS de Macao           4
# Danemark                       4
# Finlande                       4
# Irlande                        4
# Islande                        4
# Luxembourg                     4
# Norvège                        4
# Pays-Bas                       4
# Suisse                         4
# Suède                          4

# %%
final_choice_clustering.groupby(by="Continent").agg(Total=('Continent','count'))
# Out:
#            Total
# Continent
# Asie           2
# Europe        12

# %%
final_choice_clustering.to_excel("selection_finale_CAH.xlsx")

# %% [markdown]
# ## Conclusion
#
# **Le partitionnement kmeans donnant trop de pays, nous sommes partis sur une sélection via la méthode de classfication ascendante hiérarchique.<br>**

# %% [markdown]
# # ACP
#
# Pour rappel, la valeur propre associée à un axe correspond à la fraction d’inertie qu’il retranscrit. Plus elle  est  élevée,  plus  le  facteur  est  important  dans  la  lecture  des  résultats. L’enjeu  justement  est  de
# déceler à partir de quel stade l’information restituée peut être considérée négligeable. En tenant compte de plusieurs  éléments
# - le  nombre d’observations «n»
# - le  nombre de  variables  «p» de l’analyse
# - le  ratio  «n:p» entre  le  nombre d’observations et le nombre de variables
# -  le  degré  de  liaison  (la  corrélation)  entre  les  variables
# -  l’existence éventuelle de blocs de variables corrélées dans le tableau de données.
#
# Le ratio  «n:p»  est  particulièrement  important,  il  détermine  la  stabilité  des  résultats.  Certaines références affirment qu’une ACP n’est vraiment viable que s’il est supérieur à 3.
#
# Nous avons 169/9 = 18.8 dans notre fichier. Nous pouvons travailler en confiance.
#
# L'ACP permet donc de trouver les directions selon lesquelles la Variance de données est maximale pour perdre le moins d'informations possible quand on les projette.
#
# On va afficher la table des valeurs propres de nos données (indiquant pour chacun des composantes, la valeur propre, le pourcentage de variance expliqué par la composante (taux d'inertie) et le pourcentage cumulé de variance expliquée pour nous aider à choisit le nombre de composantes.
#
# <u>Quelques méthodes pour choisir le nombre de composantes principales à conserver</u> :
#
# 1. **La qualité de représentation du nuage de points** Comme le nombre de CP est égal au nombre de variables d'origine, il ne faut retenir que les CP qui expliquent le plus la variance (70-95%) pour faciliter l'interprétation. Plus les CP conservées expliquent la majorité des variations dans les données d'origine, meilleur sera le modèle PCA. Ceci est hautement subjectif et basé sur l'interprétation de l'utilisateur.=> <u>Méthode à ne pas utiliser seule.</u>
#
# 2. **Le critère de Kayser** : Dans une ACP normée, la somme des valeurs propres étant égale  au  nombre  de  variables,leur moyenne vaut 1.  Nous  considérons par  conséquent qu’un axe est intéressant si sa valeur propre est supérieure à 1. Généralement, les CP avec des valeurs propres> 1 contribuent à une plus grande variance et doivent être conservés pour une analyse plus approfondie.<br>
# On peut aussi le calculer ainsi : on a tendance à ne pas considérer comme importants les axes dont l’inertie associée est inférieure à (100/p)% , car ils représentent moins de variabilité qu’une seule variable initiale. La valeur de (100/p)% est celle obtenue quand toutes les variables sont indépendantes deux à deux. => <u>Méthode à ne pas utiliser en tout cas pas seule.</u>
#
# 3. **La règle de Règle de Karlis – Saporta - Spinaki.** On pense  généralement que le seuil de 1 est trop permissif. Une règle plus restrictive consiste à le définir comme suit: moyenne des valeurs propres  +  2  fois  leur  écart-type. Nous serons d’autant plus exigeants (enclins à accepter moins de facteurs) que le nombre de variables «p» est élevé par rapport aux observations disponibles «n».<br>
# Formule : 1+2(racine carrée de p-1/n-1)<br>
#     Dans notre cas : <br>
#     1+2(√(9-1)/(169-1))<br>
#     1+2(√0.047)<br>
#     =1.44<br>
#
# 4. **Le Scree plot ou l'éboulis des valeurs propres  ou scree-test ou test d'accumulation** est une autre technique graphique utile dans la rétention des CP qui consiste à regarder comment évoluent les valeurs propres en fonction de leur ordre d'extraction. Le terme « scree » fait référence à l'accumulation de dépôts rocheux au pied d'une montagne créant ainsi un petit promontoire à l'endroit où le dénivelé de la montagne se transforme en une pente plus douce. On ne retient justement que les composantes qui précédent le passage à cette pente douce, donc au niveau du changement brusque.

# %% [markdown]
# ## Choix du nombre de composantes - Librairie sklearn.decomposition

# %% [markdown]
# Je repars de mes données centrées et réduites que j'ai dans XCR ou XCR_km (données légèrement différentes car le centrage réduction a été réalisé différemment).

# %%
pd.DataFrame(XCR)
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.242418 -0.883583 -2.811795 -0.097727 -1.425033 -1.290025 -1.170078
# 1    0.033985 -0.310146  0.019221  0.415483 -0.008053 -0.063747  1.805665
# 2   -1.391694 -0.363074  0.165847 -0.675739  0.497264  1.176883 -0.720307
# 3    0.373432 -0.413295 -1.232742  0.869676 -0.985493 -0.588704 -0.925768
# 4   -0.943624  1.595069  1.011768 -0.050283  1.080654  1.275160 -0.515708
# ..        ...       ...       ...       ...       ...       ...       ...
# 164  2.593419  2.280755  0.989210 -1.143433 -0.669516 -0.127725  2.107815
# 165  0.122241 -0.419101 -0.375542  0.883563  0.228622 -0.308954  0.123123
# 166 -0.509131  1.927575  0.673400  0.870641  1.308723  1.765574  0.750731
# 167  1.106639 -0.885372 -1.695179  0.745858 -2.079118 -1.520393 -1.548197
# 168  0.923337 -0.854183  0.459100 -2.973708 -0.887749 -1.064279 -0.753975
#
#             7         8
# 0   -0.694692  0.231734
# 1   -0.837603  0.231734
# 2    0.528764  0.124438
# 3   -1.105996  0.231734
# 4    0.528764  0.996219
# ..        ...       ...
# 164  0.528764  0.915747
# 165 -1.210565  0.258558
# 166  0.528764 -1.900776
# 167 -1.959975  0.231734
# 168  0.528764  0.151262
#
# [169 rows x 9 columns]

# %%
XCR_km
# Out:
#                        Evolution pop (%)  PIB par hab.  Stabilité politique  \
# Zone
# Afghanistan                     1.238737     -0.880965            -2.803464
# Afrique du Sud                  0.033884     -0.309227             0.019164
# Albanie                        -1.387571     -0.361998             0.165356
# Algérie                         0.372326     -0.412070            -1.229090
# Allemagne                      -0.940828      1.590343             1.008770
# ...                                  ...           ...                  ...
# Émirats arabes unis             2.585734      2.273998             0.986279
# Équateur                        0.121879     -0.417859            -0.374430
# États-Unis d'Amérique          -0.507622      1.921864             0.671405
# Éthiopie                        1.103360     -0.882748            -1.690156
# Îles Salomon                    0.920601     -0.851652             0.457740
#
#                        Part non importée volailles (%)  \
# Zone
# Afghanistan                                  -0.097437
# Afrique du Sud                                0.414252
# Albanie                                      -0.673737
# Algérie                                       0.867100
# Allemagne                                    -0.050134
# ...                                                ...
# Émirats arabes unis                          -1.140045
# Équateur                                      0.880945
# États-Unis d'Amérique                         0.868061
# Éthiopie                                      0.743648
# Îles Salomon                                 -2.964897
#
#                        Protéines animales (%)  \
# Zone
# Afghanistan                         -1.420811
# Afrique du Sud                      -0.008030
# Albanie                              0.495791
# Algérie                             -0.982573
# Allemagne                            1.077452
# ...                                       ...
# Émirats arabes unis                 -0.667532
# Équateur                             0.227945
# États-Unis d'Amérique                1.304845
# Éthiopie                            -2.072958
# Îles Salomon                        -0.885118
#
#                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                         -1.286203
# Afrique du Sud                                      -0.063558
# Albanie                                              1.173396
# Algérie                                             -0.586960
# Allemagne                                            1.271382
# ...                                                       ...
# Émirats arabes unis                                 -0.127346
# Équateur                                            -0.308039
# États-Unis d'Amérique                                1.760343
# Éthiopie                                            -1.515888
# Îles Salomon                                        -1.061125
#
#                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Afghanistan                                            -1.166611
# Afrique du Sud                                          1.800315
# Albanie                                                -0.718172
# Algérie                                                -0.923025
# Allemagne                                              -0.514180
# ...                                                          ...
# Émirats arabes unis                                     2.101570
# Équateur                                                0.122758
# États-Unis d'Amérique                                   0.748507
# Éthiopie                                               -1.543610
# Îles Salomon                                           -0.751741
#
#                        Part non perdue (%)  Saturation du marché
# Zone
# Afghanistan                      -0.692634              0.231048
# Afrique du Sud                   -0.835121              0.231048
# Albanie                           0.527197              0.124069
# Algérie                          -1.102719              0.231048
# Allemagne                         0.527197              0.993267
# ...                                    ...                   ...
# Émirats arabes unis               0.527197              0.913034
# Équateur                         -1.206978              0.257792
# États-Unis d'Amérique             0.527197             -1.895144
# Éthiopie                         -1.954168              0.231048
# Îles Salomon                      0.527197              0.150814
#
# [169 rows x 9 columns]

# %%
n_components = 9 # La totalité de mes variables

decomposition_PCA = PCA # pour différencier ce PCA du PCA de sklearn.decomposition du suivant

model_pca = decomposition_PCA(n_components=n_components) # Si on veut garder toutes les variables, on n'est pas obligé de préciser l'attribut n_components
#model_pca.fit(XCR)
res_pca=model_pca.fit_transform(XCR_km)
#X_trans = res_pca.transform(XCR) # projection des données

# %% [markdown]
# Affichage des valeurs de l'ACP

# %%
eigen_values=model_pca.explained_variance_
explained_variance_ratio=model_pca.explained_variance_ratio_
explained_variance_ratio_cumsum=model_pca.explained_variance_ratio_.cumsum()

sklearn_pca_df=pd.DataFrame(index=["Valeur propre","Ration variance expliquée","Ratio Var. cumulée expliquée"], data=[eigen_values,explained_variance_ratio,explained_variance_ratio_cumsum])
sklearn_pca_df
# Out:
#                                      0         1         2         3  \
# Valeur propre                 3.714922  1.410511  0.989419  0.898269
# Ration variance expliquée     0.412769  0.156723  0.109935  0.099808
# Ratio Var. cumulée expliquée  0.412769  0.569492  0.679428  0.779236
#
#                                      4         5         6         7         8
# Valeur propre                 0.735470  0.520546  0.403707  0.262061  0.065096
# Ration variance expliquée     0.081719  0.057838  0.044856  0.029118  0.007233
# Ratio Var. cumulée expliquée  0.860954  0.918793  0.963649  0.992767  1.000000

# %% [markdown]
# Affichage des vecteurs propres

# %%
eigen_vectors=model_pca.components_
pd.DataFrame(eigen_vectors)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.275532  0.405792  0.417138 -0.166186  0.474029  0.477861  0.130436
# 1 -0.388106  0.006627 -0.128603  0.616046  0.106298  0.143788 -0.267671
# 2  0.104423  0.270602  0.036263 -0.245010  0.069381  0.155669 -0.740982
# 3 -0.039742  0.164339 -0.064305  0.279924  0.149544  0.124650  0.531606
# 4  0.788032  0.432953  0.046553  0.198966 -0.002684  0.056958  0.096530
# 5 -0.025425 -0.229124  0.082998 -0.580069  0.089310 -0.008456  0.228693
# 6  0.000001  0.137379 -0.888920 -0.230474  0.222631  0.248421  0.051692
# 7 -0.371435  0.667246 -0.061836 -0.158603 -0.533547 -0.277775  0.112153
# 8 -0.036979  0.176123 -0.030794  0.011874  0.628172 -0.754331 -0.053012
#
#           7         8
# 0  0.254013 -0.152323
# 1 -0.406358 -0.429569
# 2 -0.340447  0.400650
# 3 -0.433593  0.616775
# 4 -0.140419 -0.342806
# 5 -0.651798 -0.343944
# 6  0.131702 -0.080835
# 7 -0.067076 -0.094503
# 8  0.006326 -0.007629

# %%
# Appel de la fonction d'affichage des données
display_scree_plot(model_pca.explained_variance_ratio_*100, model_pca.explained_variance_ratio_.cumsum()*100)

# %% [markdown]
# **Observation**<br>
# On remarque ici que deux dimensions suffisent à expliquer + de la moitié (57%) de la variance des données.<br>
# La méthode du coude indique que 2 composantes seraient suffisantes. <br>
# Les valeurs propres > 1, et même quasiment > 1.44 avec le test plus restrictif, concernent les 2 premières composantes.
# -----------

# %% [markdown]
# ## Choix du nombre de composantes - Librairie fanalysis
# Calcul de l'ACP avec la librairie fanalysis, plus simple pour gérer les graphiques liés à l'ACP (comme le cercle de corrélation)

# %%
from fanalysis.pca import PCA

fanalysis_PCA = PCA

pca_df=main_df.iloc[:,1:10].copy()

model2_pca = fanalysis_PCA(std_unit=True, row_labels=pca_df.index.values, col_labels=pca_df.columns.values) #std_unit to indicate if we normalize or not the data
res2_pca=model2_pca.fit_transform(pca_df.to_numpy())
#my_pca.fit(pca_df.to_numpy())

#my_pca.plot_eigenvalues(type="percentage") 

pd.DataFrame(model2_pca.eig_,index=["Valeur propre","% Variance expliquée","% Var. cumulée expliquée"])
# Out:
#                                   0          1          2          3  \
# Valeur propre              3.714922   1.410511   0.989419   0.898269
# % Variance expliquée      41.276906  15.672342  10.993542   9.980770
# % Var. cumulée expliquée  41.276906  56.949248  67.942789  77.923559
#
#                                   4          5          6          7  \
# Valeur propre              0.735470   0.520546   0.403707   0.262061
# % Variance expliquée       8.171887   5.783840   4.485635   2.911786
# % Var. cumulée expliquée  86.095446  91.879286  96.364921  99.276707
#
#                                    8
# Valeur propre               0.065096
# % Variance expliquée        0.723293
# % Var. cumulée expliquée  100.000000

# %% [markdown]
# Affichage des vecteurs propres

# %%
pd.DataFrame(model2_pca.eigen_vectors_)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.275532 -0.388106  0.104423 -0.039742  0.788032  0.025425 -0.000001
# 1  0.405792  0.006627  0.270602  0.164339  0.432953  0.229124 -0.137379
# 2  0.417138 -0.128603  0.036263 -0.064305  0.046553 -0.082998  0.888920
# 3 -0.166186  0.616046 -0.245010  0.279924  0.198966  0.580069  0.230474
# 4  0.474029  0.106298  0.069381  0.149544 -0.002684 -0.089310 -0.222631
# 5  0.477861  0.143788  0.155669  0.124650  0.056958  0.008456 -0.248421
# 6  0.130436 -0.267671 -0.740982  0.531606  0.096530 -0.228693 -0.051692
# 7  0.254013 -0.406358 -0.340447 -0.433593 -0.140419  0.651798 -0.131702
# 8 -0.152323 -0.429569  0.400650  0.616775 -0.342806  0.343944  0.080835
#
#           7         8
# 0 -0.371435 -0.036979
# 1  0.667246  0.176123
# 2 -0.061836 -0.030794
# 3 -0.158603  0.011874
# 4 -0.533547  0.628172
# 5 -0.277775 -0.754331
# 6  0.112153 -0.053012
# 7 -0.067076  0.006326
# 8 -0.094503 -0.007629

# %% [markdown]
# **Observation**<br>
# Ce tableau de composantes n'est pas ordonné comme il faut contrairement à eigen_vectors plus haut. Les lignes et les colonnes sont inverséses.<br>
#
# F1 (voir plus bas) est une combinaison linéaire des autres variables.
# On prend la ligne 0 des données centrées réduites et la ligne 0 du tableau
#
# J'ai pu vérifier le bon tableau en multipliant toutes les valeurs de la 1res lignes d'un tableau de vecteurs propres (puis l'autre pour comparer) par la 1re ligne du tableau de données centrées et réduites.
# La somme doit donner la valeur de F1 de la variable concernée (https://openclassrooms.com/fr/courses/4525281-realisez-une-analyse-exploratoire-de-donnees/5278723-interpretez-le-cercle-des-correlations)
# _____________________

# %% [markdown]
# Affichage de l'éboulis des valeurs propres

# %%
display_scree_plot(model2_pca.eig_[1],model2_pca.eig_[2])

# %% [markdown]
# **Observation**<br>
# Le résultat entre les 2 méthodes est le même (avec des chiffres sensiblement différents qui ne changent pas les pourcentages finaux).<br>
# On reste sur 2 composantes principales pour expliquer la variance de 57% de nos données.
# _______________

# %% [markdown]
# ## Analyse

# %% [markdown]
# Je vérifie que les variables sont bien décorrélées (même si je n'avais pas vérifié avant car on avait beaucoup de variables)

# %%
from scipy.stats import pearsonr

comp1=res2_pca[:,0]
comp2=res2_pca[:,1]
coef_corr_comp, p_value_comp = pearsonr(comp1, comp2)
print(coef_corr_comp, p_value_comp)
# Out:
# -2.5326962749261384e-16 0.999999999999997

# %% [markdown]
# **Observation**<br>
# Il n'y a pas de corrélation linéaires entre les 2 composantes, le coefficient de corrélation est proche de 0 et une p-value valant 1, ce qui signifie qu'on accèpte l'hypothèse nulle (les varaiables sont indépendantes).<br>
# L'ACP transforme un jeu de variables en un nouvel ensemble de variables non corrélées.
# _____________________

# %% [markdown]
# Affichage
# - du cercle de corrélation regroupant les 2 1res composantes
# - des tableaux de contribution des 2 variables du 1er plan factoriel.

# %%
model2_pca.correlation_circle(num_x_axis=1, num_y_axis=2,figsize=(20,20))
#model2_pca.correlation_circle(num_x_axis=3, num_y_axis=4,figsize=(20,20))
model2_pca.plot_col_contrib(1,n_components)
model2_pca.plot_col_contrib(2,n_components)

# %% [markdown]
# **Observation**<br>
# Les axes factoriels sont des axes virtuels issus d’une synthèse entre les variables de l’analyse. Ils n’ont pas nécessairement un sens précis même si on peut souvent leur trouver un sens en s’aidant notamment de la représentation des variable sur le cercle de corrélation.
#
# Les 2 variables *Protéines animales* et *Dispo prot animale sur besoin prot (%)* sont très proches du cercle de corrélation et donc très bien représentés sur le mapping. l'**axe 1**. On peut avancer qu'elles sont corrélées entre elles (très faible angle entre les 2 et flèches proches de 1).<br>
# On voit aussi une corrélation positive sur cet axe de *Stabilité politique* et *PIB*.<br>
#
# L'*"Part non importée volailles"* est la variable qui contribue le + à l'**axe 2**. Les 3 variables suivantes, participant à F2 sont négatives.<br>
#
# La protéine de volaille n'a pas d'influence sur les 2 axes, la variable est mal représentée.
#
# De ces observations, nous pouvons conclure que l'**axe 1** correspond aux pays plutôt carnivores (2 1res contributions) et riches (2 contributions suivantes). On pourrait extrapoler et résumer l'axe en **"Pays riches"** si on considère que les pays riches consomment plus de viande (même s'il y a des exceptions culturelles liées au statut de pays plutôt végétarien). <br>
# L'**axe 2 renseignerait sur le marché** en lui-même.
#
# _______________________

# %% [markdown]
# Validation majorité des cas : pays stables = pays riches. Faire varier le signe < > sur les 2 variables.

# %%
main_df[(main_df["Stabilité politique"]<=0)&(main_df["PIB par hab."]>np.mean(main_df["PIB par hab."]))].shape[0]
# Out:
# 6

# %% [markdown]
# # Clustering sur ACP
# On fait le clustering sur l'ACP sur les variables initiales et pas synthétiques. Il ne faut pas centrer et réduire pour ne pas éliminer l'importance entre les axes, on ne veut pas donner autant d'importance à chaque dimension.<br>
# Normalement les boxplot avec le plus de différence sont ceux des variables qui contribuaientt au deux premiers axes.

# %% [markdown]
# Coordonnées des coefficients de corrélation des individus

# %%
print("Coordonnées des coefficients de corrélation des individus")
res2_pca_df=pd.DataFrame(res2_pca[:,0:2],columns=["F1","F2"], index=main_df.index)
#res2_pca_df=pd.DataFrame(res2_pca[:,0:4],columns=["F1","F2","F3","F4"], index=main_df.index) si 4 composantes
res2_pca_df
# Out:
# Coordonnées des coefficients de corrélation des individus
#                              F1        F2
# Zone
# Afghanistan           -3.513882 -0.027671
# Afrique du Sud        -0.243065 -0.014286
# Albanie                1.237112  0.246668
# Algérie               -2.114817  0.954905
# Allemagne              2.374577  0.009158
# ...                         ...       ...
# Émirats arabes unis    0.704956 -3.085007
# Équateur              -0.877326  0.870166
# États-Unis d'Amérique  3.044527  1.453808
# Éthiopie              -3.942464  0.913818
# Îles Salomon          -0.831801 -2.580421
#
# [169 rows x 2 columns]

# %%
final_df=pd.concat([main_df, res2_pca_df], axis=1)
final_df
# Out:
#                        Continent  Evolution pop (%)  PIB par hab.  \
# Zone
# Afghanistan                 Asie               3.39        2058.4
# Afrique du Sud           Afrique               1.61       13860.3
# Albanie                   Europe              -0.49       12771.0
# Algérie                  Afrique               2.11       11737.4
# Allemagne                 Europe               0.17       53071.5
# ...                          ...                ...           ...
# Émirats arabes unis         Asie               5.38       67183.6
# Équateur               Amériques               1.74       11617.9
# États-Unis d'Amérique  Amériques               0.81       59914.8
# Éthiopie                 Afrique               3.19        2021.6
# Îles Salomon             Océanie               2.92        2663.5
#
#                        Stabilité politique  Part non importée volailles (%)  \
# Zone
# Afghanistan                          -2.57                            49.12
# Afrique du Sud                       -0.06                            75.73
# Albanie                               0.07                            19.15
# Algérie                              -1.17                            99.28
# Allemagne                             0.82                            51.58
# ...                                    ...                              ...
# Émirats arabes unis                   0.80                            -5.10
# Équateur                             -0.41                           100.00
# États-Unis d'Amérique                 0.52                            99.33
# Éthiopie                             -1.58                            92.86
# Îles Salomon                          0.33                          -100.00
#
#                        Protéines animales (%)  \
# Zone
# Afghanistan                             19.78
# Afrique du Sud                          42.83
# Albanie                                 51.05
# Algérie                                 26.93
# Allemagne                               60.54
# ...                                       ...
# Émirats arabes unis                     32.07
# Équateur                                46.68
# États-Unis d'Amérique                   64.25
# Éthiopie                                 9.14
# Îles Salomon                            28.52
#
#                        Dispo prot animale sur besoin prot (%)  \
# Zone
# Afghanistan                                             21.57
# Afrique du Sud                                          71.98
# Albanie                                                122.98
# Algérie                                                 50.40
# Allemagne                                              127.02
# ...                                                       ...
# Émirats arabes unis                                     69.35
# Équateur                                                61.90
# États-Unis d'Amérique                                  147.18
# Éthiopie                                                12.10
# Îles Salomon                                            30.85
#
#                        Prot. de volailles sur prot. animales (%)  \
# Zone
# Afghanistan                                                 5.05
# Afrique du Sud                                             39.52
# Albanie                                                    10.26
# Algérie                                                     7.88
# Allemagne                                                  12.63
# ...                                                          ...
# Émirats arabes unis                                        43.02
# Équateur                                                   20.03
# États-Unis d'Amérique                                      27.30
# Éthiopie                                                    0.67
# Îles Salomon                                                9.87
#
#                        Part non perdue (%)  Saturation du marché  CAH  Kmeans  \
# Zone
# Afghanistan                          96.49                   0.0    5       1
# Afrique du Sud                       96.08                   0.0    3       5
# Albanie                             100.00                  -8.0    3       4
# Algérie                              95.31                   0.0    5       1
# Allemagne                           100.00                  57.0    1       4
# ...                                    ...                   ...  ...     ...
# Émirats arabes unis                 100.00                  51.0    4       3
# Équateur                             95.01                   2.0    5       5
# États-Unis d'Amérique               100.00                -159.0    2       2
# Éthiopie                             92.86                   0.0    5       1
# Îles Salomon                        100.00                  -6.0    4       3
#
#                              F1        F2
# Zone
# Afghanistan           -3.513882 -0.027671
# Afrique du Sud        -0.243065 -0.014286
# Albanie                1.237112  0.246668
# Algérie               -2.114817  0.954905
# Allemagne              2.374577  0.009158
# ...                         ...       ...
# Émirats arabes unis    0.704956 -3.085007
# Équateur              -0.877326  0.870166
# États-Unis d'Amérique  3.044527  1.453808
# Éthiopie              -3.942464  0.913818
# Îles Salomon          -0.831801 -2.580421
#
# [169 rows x 14 columns]

# %%
components_df=final_df.iloc[:,[0,-2,-1]].copy()
components_df_num=components_df.iloc[:,[1,2]]
#comp_df=final_df.iloc[:,[0,-4,-3,-2,-1]].copy() si 4 composantes
#comp_df_num=comp_df.iloc[:,[1,2,3,4]]
components_df_num
# Out:
#                              F1        F2
# Zone
# Afghanistan           -3.513882 -0.027671
# Afrique du Sud        -0.243065 -0.014286
# Albanie                1.237112  0.246668
# Algérie               -2.114817  0.954905
# Allemagne              2.374577  0.009158
# ...                         ...       ...
# Émirats arabes unis    0.704956 -3.085007
# Équateur              -0.877326  0.870166
# États-Unis d'Amérique  3.044527  1.453808
# Éthiopie              -3.942464  0.913818
# Îles Salomon          -0.831801 -2.580421
#
# [169 rows x 2 columns]

# %%
best_linkage_ach(components_df_num)
# Out:
# La meilleure méthode théorique de lien est la 'average'.

# %%
Z = linkage(components_df_num, method="ward",metric="euclidean")
plot_dendrogram(components_df_num,Z,7)

# %% [markdown]
# **Observation**<br>
# Avec 7 clusters, les branches de chaque arbre sont assez longues et on a un découpage plus intéressant qu'avec 3 groupes.

# %%
number_of_clusters=7 # Clusters are colored on the dendogram above
groups_ACP = fcluster(Z, number_of_clusters, criterion='maxclust') # ou fcluster(Z, threshold, criterion='distance')

display_countries_from_clusters(number_of_clusters, groups_ACP)
# Out:
# Affichage des 7 clusters
#
# Cluster 1 :
# Allemagne, Antigua-et-Barbuda, Autriche, Bahamas, Belgique, Chine - RAS de Hong-Kong, Chine - RAS de Macao, Danemark, Dominique, Irlande, Luxembourg, Malte, Mongolie, Nouvelle-Calédonie, Pays-Bas, Polynésie française, Saint-Kitts-et-Nevis, Saint-Vincent-et-les Grenadines, Samoa, Suisse
#
# Cluster 2 :
# Argentine, Australie, Bélarus, Espagne, Finlande, France, Grèce, Hongrie, Islande, Italie, Lituanie, Malaisie, Norvège, Pologne, Portugal, Roumanie, République de Corée, Suède, États-Unis d'Amérique
#
# Cluster 3 :
# Afrique du Sud, Albanie, Arménie, Barbade, Botswana, Brésil, Bulgarie, Canada, Chili, Chine, Taiwan Province de, Chypre, Costa Rica, Croatie, Cuba, Estonie, Fidji, Fédération de Russie, Guyana, Géorgie, Israël, Jamaïque, Kazakhstan, Kiribati, Lettonie, Macédoine du Nord, Maurice, Monténégro, Nouvelle-Zélande, Panama, Royaume-Uni de Grande-Bretagne et d'Irlande du Nord, République de Moldova, République dominicaine, Serbie, Slovaquie, Slovénie, Suriname, Tchéquie, Trinité-et-Tobago, Uruguay
#
# Cluster 4 :
# Angola, Arabie saoudite, Bénin, Cabo Verde, Congo, Gabon, Gambie, Grenade, Jordanie, Koweït, Libéria, Maldives, Namibie, Oman, Sainte-Lucie, Sao Tomé-et-Principe, Timor-Leste, Vanuatu, Émirats arabes unis, Îles Salomon
#
# Cluster 5 :
# Afghanistan, Bangladesh, Burkina Faso, Cameroun, Côte d'Ivoire, Inde, Kenya, Madagascar, Malawi, Mali, Niger, Nigéria, Népal, Ouganda, Pakistan, Rwanda, République-Unie de Tanzanie, Soudan, Sénégal, Yémen, Éthiopie
#
# Cluster 6 :
# Belize, Djibouti, Ghana, Guatemala, Guinée, Guinée-Bissau, Haïti, Honduras, Iran (République islamique d'), Iraq, Kirghizistan, Lesotho, Liban, Mauritanie, Mozambique, Nicaragua, Sierra Leone, Tadjikistan, Tchad, Togo, Zambie, Égypte
#
# Cluster 7 :
# Algérie, Azerbaïdjan, Bolivie (État plurinational de), Bosnie-Herzégovine, Cambodge, Chine, continentale, Colombie, El Salvador, Eswatini, Indonésie, Maroc, Mexique, Myanmar, Paraguay, Philippines, Pérou, République centrafricaine, République populaire démocratique de Corée, Sri Lanka, Thaïlande, Tunisie, Turkménistan, Turquie, Ukraine, Venezuela (République bolivarienne du), Viet Nam, Zimbabwe, Équateur

# %% [markdown]
# **INFORMATIONS RELATIVES A LA CONSOMMATION DE VIANDES**<br>
# <u>Top 5 pays végétariens</u><br>
# - L’Inde : 39 % de végétariens en 2021 (groupe 5)<br>
# - Le Mexique : 20 % (2018) (groupe 7)<br>
# - Le Brésil : 14 % de végétariens et véganes (2018) (groupe 3)<br>
# - Taïwan et Israël : 13 %, végétariens et véganes confondus (2019 et 2015) (groupes 3)<br>
#
# <u> Top 5 des pays les plus consommateurs de viande - Par kg de viande par personne par an</u>
# - USA – 120kg (groupe 2)
# - Koweït – 119.2kg (groupe 4)
# - Australie – 111.5kg (groupe 2)
# - Les Bahamas – 109.5kg (groupe 1)
# - Luxembourg – 107.9kg (groupe 1)
#
# <u> Top 5 des pays les moins consommateurs de viande - Par kg de viande par personne par an</u>
# - Bangladesh - 4kg (groupe 5)
# - Inde - 4.4kg (groupe 5)
# - Burundi - 5.2kg
# - Sri Lanka - 6.3kg (groupe 7)
# - Rwanda - 6.5kg

# %% [markdown]
# Ajout du numéro de groupe aux dataframes

# %%
main_df["ACP"]=groups_ACP
final_df["ACP"]=groups_ACP

# %% [markdown]
# ## Projection des résultats

# %% [markdown]
# Calcul de la moyenne de chaque groupe et projection

# %%
centroid=final_df.groupby(by=["ACP"], as_index=False).agg({'F1':'mean','F2':"mean"}) #si 4 composantes {'F1':'mean','F2':"mean",'F3':'mean','F4':"mean"}) 
centroid
# Out:
#    ACP        F1        F2
# 0    1  2.649083 -0.864194
# 1    2  2.199340  1.574534
# 2    3  0.999659  0.165524
# 3    4 -0.385451 -2.007488
# 4    5 -2.995877  0.595065
# 5    6 -1.589534 -0.688994
# 6    7 -1.005844  0.847270

# %% [markdown]
# On regarde avant la projection des individus avec les clusters CAH et kmeans.

# %%
display_factorial_planes(X_projected=res2_pca, n_comp=n_components, pca=model2_pca, axis_ranks=[(0,1)],  alpha = 0.5, illustrative_var=main_df.Kmeans, title_type='individus',title_nb_of_indiv=res2_pca.shape[0],labels=main_df.index, method="Kmeans")
display_factorial_planes(X_projected=res2_pca, n_comp=n_components, pca=model2_pca, axis_ranks=[(0,1)],  alpha = 0.5, illustrative_var=main_df.CAH, title_type='individus',title_nb_of_indiv=res2_pca.shape[0],labels=main_df.index, method="CAH")

# %% [markdown]
# Projection des individus et des centroïdes avec visualisation clustering sur ACP

# %%
display_factorial_planes(X_projected=res2_pca, n_comp=n_components, pca=model2_pca, axis_ranks=[(0,1)],  alpha = 0.5, illustrative_var=main_df.ACP, title_type='individus',title_nb_of_indiv=res2_pca.shape[0],labels=main_df.index, method="ACP")

display_factorial_planes(X_projected=centroid.to_numpy(), n_comp=5, axis_ranks=[(1,2)], alpha = 0.5, illustrative_var=centroid.ACP, title_type='centres',title_nb_of_indiv=centroid.shape[0],labels=centroid.index+1, method="ACP")

# %% [markdown]
# **Observation**<br>
# Le regroupement est plus pertinent sur le clustering sur ACP, on n'a pas de superposition de pays de différents groupes.
# ________________________

# %%
main_df[(main_df.index=="Pérou")|(main_df.index=="Pologne")|(main_df.index=="Inde")|(main_df.index.str.contains("Hong-Kong"))]
# Out:
#                           Continent  Evolution pop (%)  PIB par hab.  \
# Zone
# Chine - RAS de Hong-Kong       Asie               0.68       59842.2
# Inde                           Asie               1.31        6182.9
# Pologne                      Europe              -0.10       30064.5
# Pérou                     Amériques               1.10       12506.5
#
#                           Stabilité politique  \
# Zone
# Chine - RAS de Hong-Kong                 0.98
# Inde                                    -1.13
# Pologne                                  0.85
# Pérou                                   -0.70
#
#                           Part non importée volailles (%)  \
# Zone
# Chine - RAS de Hong-Kong                          -223.93
# Inde                                               100.00
# Pologne                                             95.24
# Pérou                                               96.06
#
#                           Protéines animales (%)  \
# Zone
# Chine - RAS de Hong-Kong                   69.41
# Inde                                       22.37
# Pologne                                    55.62
# Pérou                                      52.69
#
#                           Dispo prot animale sur besoin prot (%)  \
# Zone
# Chine - RAS de Hong-Kong                                  192.94
# Inde                                                       29.64
# Pologne                                                   115.52
# Pérou                                                      83.27
#
#                           Prot. de volailles sur prot. animales (%)  \
# Zone
# Chine - RAS de Hong-Kong                                      23.26
# Inde                                                           5.10
# Pologne                                                       21.19
# Pérou                                                         16.25
#
#                           Part non perdue (%)  Saturation du marché  CAH  \
# Zone
# Chine - RAS de Hong-Kong               100.00                  24.0    1
# Inde                                    81.02                 238.0    5
# Pologne                                 97.66                -450.0    2
# Pérou                                   79.25                  -1.0    5
#
#                           Kmeans  ACP
# Zone
# Chine - RAS de Hong-Kong       4    1
# Inde                           1    5
# Pologne                        2    2
# Pérou                          1    7

# %% [markdown]
# **Observation**<br>
# Les pays en haut à droite, éloignés de l'axe F2, comme la Pologne dans le cas extrême, ont une saturation de marché trop élevé pour être retenus.<br>
#
# Les pays à gauche de l'axe F2 et proches de l'axe auront une part d'import élevé. Le Pérou a beaucoup de pertes, l'Inde également et en plus est un pays qui ne consomme pas beaucoup de viande (proche de F1 négativement et très éloigné de F2).<br>
# On voit que les pays du groupe 5 se trouvent dans le quart haut gauche, ce qui le rend inintéressants de manière général.
#
# Le groupe 4 a une bonne évolution de la population et un marché non saturé. Il est situé sur la gauche de F1 en négatif car il n'a pas un bon PIB ni une bonne stabilité politique.
#
# Les pays au centre de la représentation sont dans la tendance générale.
#
# **On recherchera idéalement des pays sous l'axe F1 et à droite de l'axe F2, donc plutôt dans le carré bas droite vers le haut : Hong-Kong, point plus visible du groupe 1 rassemble toutes les qualités d'un pays candidat à part l'import qui est trop important.**
# _______________________________

# %% [markdown]
# # Conclusion

# %%
for item in main_df.columns[1:len(main_df.columns)-3]:
    build_plot(main_df,item, "ACP")

# %%
build_clustermap(main_df[main_df.columns.difference(["Continent", "CAH","Kmeans"])],"ACP")

# %% [markdown]
# **Observation**<br>
# Les pays du groupe 1 sont ceux qui ont les meilleurs résultats, sauf que ce sont les pays qui ont globalement le plus recours à l'importation. Ils ne sont pas 1ers sur la part de protéines de volaille ce qui est intéressant dans notre cas.

# %%
final_choice=main_df[main_df["ACP"]==1].sort_values(["Continent","Zone"],ascending = [True, True])
final_choice
# Out:
#                                  Continent  Evolution pop (%)  PIB par hab.  \
# Zone
# Antigua-et-Barbuda               Amériques               1.36       19840.3
# Bahamas                          Amériques               1.31       35911.7
# Dominique                        Amériques               0.09       11341.3
# Saint-Kitts-et-Nevis             Amériques               0.89       26980.3
# Saint-Vincent-et-les Grenadines  Amériques               0.12       13102.1
# Chine - RAS de Hong-Kong              Asie               0.68       59842.2
# Chine - RAS de Macao                  Asie               2.34      126144.0
# Mongolie                              Asie               2.00       11366.3
# Allemagne                           Europe               0.17       53071.5
# Autriche                            Europe               0.61       54173.0
# Belgique                            Europe               0.68       50442.3
# Danemark                            Europe               0.48       55356.7
# Irlande                             Europe               0.99       77749.2
# Luxembourg                          Europe               2.46      114986.0
# Malte                               Europe               0.74       43559.3
# Pays-Bas                            Europe               0.31       55088.6
# Suisse                              Europe               1.22       69103.6
# Nouvelle-Calédonie                 Océanie               1.39       31100.0
# Polynésie française                Océanie               0.51       17000.0
# Samoa                              Océanie               0.73        6486.1
#
#                                  Stabilité politique  \
# Zone
# Antigua-et-Barbuda                              0.89
# Bahamas                                         0.96
# Dominique                                       0.99
# Saint-Kitts-et-Nevis                            0.83
# Saint-Vincent-et-les Grenadines                 0.86
# Chine - RAS de Hong-Kong                        0.98
# Chine - RAS de Macao                            0.85
# Mongolie                                        0.64
# Allemagne                                       0.82
# Autriche                                        1.20
# Belgique                                        0.73
# Danemark                                        0.98
# Irlande                                         1.01
# Luxembourg                                      1.41
# Malte                                           1.16
# Pays-Bas                                        0.98
# Suisse                                          1.31
# Nouvelle-Calédonie                              0.45
# Polynésie française                            -0.07
# Samoa                                           1.04
#
#                                  Part non importée volailles (%)  \
# Zone
# Antigua-et-Barbuda                                          0.00
# Bahamas                                                     7.69
# Dominique                                                   0.00
# Saint-Kitts-et-Nevis                                        0.00
# Saint-Vincent-et-les Grenadines                           -12.50
# Chine - RAS de Hong-Kong                                 -223.93
# Chine - RAS de Macao                                      -21.05
# Mongolie                                                  -11.11
# Allemagne                                                  51.58
# Autriche                                                   36.42
# Belgique                                                 -122.37
# Danemark                                                   20.36
# Irlande                                                    22.66
# Luxembourg                                                  0.00
# Malte                                                      35.71
# Pays-Bas                                                  -63.44
# Suisse                                                     61.65
# Nouvelle-Calédonie                                         18.18
# Polynésie française                                         0.00
# Samoa                                                     -13.33
#
#                                  Protéines animales (%)  \
# Zone
# Antigua-et-Barbuda                                77.67
# Bahamas                                           89.00
# Dominique                                         58.64
# Saint-Kitts-et-Nevis                              64.35
# Saint-Vincent-et-les Grenadines                   55.29
# Chine - RAS de Hong-Kong                          69.41
# Chine - RAS de Macao                              67.75
# Mongolie                                          77.72
# Allemagne                                         60.54
# Autriche                                          59.85
# Belgique                                          56.93
# Danemark                                          68.19
# Irlande                                           64.27
# Luxembourg                                        63.90
# Malte                                             55.62
# Pays-Bas                                          65.12
# Suisse                                            63.59
# Nouvelle-Calédonie                                60.51
# Polynésie française                               63.89
# Samoa                                             61.03
#
#                                  Dispo prot animale sur besoin prot (%)  \
# Zone
# Antigua-et-Barbuda                                               127.08
# Bahamas                                                          110.12
# Dominique                                                         93.35
# Saint-Kitts-et-Nevis                                              99.72
# Saint-Vincent-et-les Grenadines                                   99.40
# Chine - RAS de Hong-Kong                                         192.94
# Chine - RAS de Macao                                             137.10
# Mongolie                                                         129.03
# Allemagne                                                        127.02
# Autriche                                                         130.44
# Belgique                                                         116.33
# Danemark                                                         155.24
# Irlande                                                          137.10
# Luxembourg                                                       136.29
# Malte                                                            130.44
# Pays-Bas                                                         137.10
# Suisse                                                           122.38
# Nouvelle-Calédonie                                               101.41
# Polynésie française                                              125.60
# Samoa                                                            105.44
#
#                                  Prot. de volailles sur prot. animales (%)  \
# Zone
# Antigua-et-Barbuda                                                   28.19
# Bahamas                                                              26.75
# Dominique                                                            24.88
# Saint-Kitts-et-Nevis                                                 38.86
# Saint-Vincent-et-les Grenadines                                      50.91
# Chine - RAS de Hong-Kong                                             23.26
# Chine - RAS de Macao                                                 17.50
# Mongolie                                                              1.48
# Allemagne                                                            12.63
# Autriche                                                             11.58
# Belgique                                                              7.92
# Danemark                                                             16.84
# Irlande                                                              17.06
# Luxembourg                                                           10.64
# Malte                                                                19.60
# Pays-Bas                                                             12.47
# Suisse                                                               10.69
# Nouvelle-Calédonie                                                   27.93
# Polynésie française                                                  26.00
# Samoa                                                                41.84
#
#                                  Part non perdue (%)  Saturation du marché  \
# Zone
# Antigua-et-Barbuda                             100.0                   0.0
# Bahamas                                        100.0                  -9.0
# Dominique                                      100.0                   1.0
# Saint-Kitts-et-Nevis                           100.0                   0.0
# Saint-Vincent-et-les Grenadines                100.0                  -2.0
# Chine - RAS de Hong-Kong                       100.0                  24.0
# Chine - RAS de Macao                           100.0                 -16.0
# Mongolie                                       100.0                  -2.0
# Allemagne                                      100.0                  57.0
# Autriche                                       100.0                 -16.0
# Belgique                                       100.0                  13.0
# Danemark                                       100.0                   0.0
# Irlande                                        100.0                  24.0
# Luxembourg                                     100.0                   1.0
# Malte                                          100.0                   2.0
# Pays-Bas                                       100.0                 164.0
# Suisse                                         100.0                 -10.0
# Nouvelle-Calédonie                             100.0                   2.0
# Polynésie française                            100.0                  -1.0
# Samoa                                          100.0                  -4.0
#
#                                  CAH  Kmeans  ACP
# Zone
# Antigua-et-Barbuda                 3       4    1
# Bahamas                            3       4    1
# Dominique                          3       4    1
# Saint-Kitts-et-Nevis               3       4    1
# Saint-Vincent-et-les Grenadines    3       5    1
# Chine - RAS de Hong-Kong           1       4    1
# Chine - RAS de Macao               1       4    1
# Mongolie                           3       4    1
# Allemagne                          1       4    1
# Autriche                           1       4    1
# Belgique                           1       4    1
# Danemark                           1       4    1
# Irlande                            1       4    1
# Luxembourg                         1       4    1
# Malte                              3       4    1
# Pays-Bas                           1       4    1
# Suisse                             1       4    1
# Nouvelle-Calédonie                 3       4    1
# Polynésie française                3       4    1
# Samoa                              3       5    1

# %% [markdown]
# **Observation**<br>
# Tous les pays font partie du groupe 4 kmeans à l'exception de 2 pays.<br>
# Ils font aussi partie des groupes 1 et 3 du clustering CAH, qui sont les 2 premiers groupes sélectionnés (le 1 étant le choix final de cette classification).
# ______________________

# %%
mean_df=final_choice[final_choice.columns.difference(['Continent','ACP','CAH','Kmeans'])].mean()
mean_df=pd.DataFrame(mean_df, columns=["Moyenne"])
mean_df
# Out:
#                                               Moyenne
# Dispo prot animale sur besoin prot (%)       125.6765
# Evolution pop (%)                              0.9540
# PIB par hab.                               46632.2250
# Part non importée volailles (%)              -10.6740
# Part non perdue (%)                          100.0000
# Prot. de volailles sur prot. animales (%)     21.3515
# Protéines animales (%)                        65.1635
# Saturation du marché                          11.4000
# Stabilité politique                            0.9010

# %% [markdown]
# Export des données finales

# %%
common_countries_with_first_selection=final_choice[final_choice.index.isin(final_choice_clustering.index)]

# %%
print (f"Le choix final comporte une sélection de {final_choice.shape[0]} pays dont {common_countries_with_first_selection.shape[0]} en commun avec la première sélection basée sur le clustering CAH.")
# Out:
# Le choix final comporte une sélection de 20 pays dont 10 en commun avec la première sélection basée sur le clustering CAH.

# %%
final_choice.to_excel("SelectionFinale.xlsx")
final_df.to_excel("DonnéesFinales.xlsx")
